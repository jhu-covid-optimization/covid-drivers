# %% [raw]
# Beatriz Medeiros
# Notebook for AC-PCA on independent and dependent variables separately

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.linear_model as lm
from collections import defaultdict
import sys; sys.path.append('../')
from src.data_analysis.tools import ac_pca

# %% [markdown]
# ## Get Preprocessed data

# %%
combined_data = pd.read_csv('../data/intermediates/pre_acpca1.csv')
combined_data.set_index('FIPS', inplace=True)
print(combined_data.shape)
ind_vars = list(combined_data.columns)
total_vars = len(ind_vars)
combined_data.head()
# Out:
# (397, 21)
#         baseline  Density per square mile of land area - Population  \
# FIPS
# 1055.0  0.449395                                           0.002718
# 1073.0  0.483877                                           0.008438
# 1081.0  0.307942                                           0.003231
# 1095.0  0.516342                                           0.002275
# 1097.0  0.456792                                           0.004744
#
#         Rural-urban_Continuum Code_2013  \
# FIPS
# 1055.0                              0.4
# 1073.0                              0.0
# 1081.0                              0.4
# 1095.0                              0.6
# 1097.0                              0.2
#
#         Percent of adults with less than a high school diploma 2014-18  \
# FIPS
# 1055.0                                           0.402985
# 1073.0                                           0.247761
# 1081.0                                           0.223881
# 1095.0                                           0.510448
# 1097.0                                           0.352239
#
#         Percent of adults with a bachelor's degree or higher 2014-18  \
# FIPS
# 1055.0                                           0.122490
# 1073.0                                           0.417671
# 1081.0                                           0.451807
# 1095.0                                           0.152610
# 1097.0                                           0.226908
#
#         Unemployment_rate_2018  Med_HH_Income_Percent_of_State_Total_2018  \
# FIPS
# 1055.0                0.135802                                   0.222485
# 1073.0                0.111111                                   0.342604
# 1081.0                0.104938                                   0.270414
# 1095.0                0.092593                                   0.238462
# 1097.0                0.172840                                   0.207101
#
#         Mar Temp AVG / F  Apr Temp AVG / F  May Temp AVG / F  ...  \
# FIPS                                                          ...
# 1055.0          0.697723          0.736148          0.781775  ...
# 1073.0          0.718427          0.751979          0.803357  ...
# 1081.0          0.757764          0.757256          0.805755  ...
# 1095.0          0.672878          0.712401          0.772182  ...
# 1097.0          0.846791          0.823219          0.868106  ...
#
#         Total_age65plus  Total households!!Average household size  \
# FIPS
# 1055.0         0.203494                                  0.325792
# 1073.0         0.138366                                  0.276018
# 1081.0         0.056305                                  0.343891
# 1095.0         0.162744                                  0.334842
# 1097.0         0.145504                                  0.303167
#
#         SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool  \
# FIPS
# 1055.0                                           0.294336
# 1073.0                                           0.520694
# 1081.0                                           0.586319
# 1095.0                                           0.241579
# 1097.0                                           0.505194
#
#         SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten  \
# FIPS
# 1055.0                                           0.358494
# 1073.0                                           0.386817
# 1081.0                                           0.144048
# 1095.0                                           0.364819
# 1097.0                                           0.328976
#
#         SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)  \
# FIPS
# 1055.0                                           0.567540
# 1073.0                                           0.576102
# 1081.0                                           0.571650
# 1095.0                                           0.680389
# 1097.0                                           0.607318
#
#         SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)  \
# FIPS
# 1055.0                                           0.342774
# 1073.0                                           0.400644
# 1081.0                                           0.427235
# 1095.0                                           0.623360
# 1097.0                                           0.491922
#
#         SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school  \
# FIPS
# 1055.0                                           0.075155
# 1073.0                                           0.172229
# 1081.0                                           0.609583
# 1095.0                                           0.086210
# 1097.0                                           0.119985
#
#           HospCt    Deaths  normalized_deaths
# FIPS
# 1055.0  0.261462  0.000986           0.028791
# 1073.0  0.169115  0.005521           0.013511
# 1081.0  0.050141  0.003943           0.046459
# 1095.0  0.281908  0.000591           0.024185
# 1097.0  0.106354  0.006901           0.028506
#
# [5 rows x 21 columns]

# %%
ind_vars
# Out:
# ['baseline',
#  'Density per square mile of land area - Population',
#  'Rural-urban_Continuum Code_2013',
#  'Percent of adults with less than a high school diploma 2014-18',
#  "Percent of adults with a bachelor's degree or higher 2014-18",
#  'Unemployment_rate_2018',
#  'Med_HH_Income_Percent_of_State_Total_2018',
#  'Mar Temp AVG / F',
#  'Apr Temp AVG / F',
#  'May Temp AVG / F',
#  'Jun Temp AVG / F',
#  'Total_age65plus',
#  'Total households!!Average household size',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school',
#  'HospCt',
#  'Deaths',
#  'normalized_deaths']

# %% [markdown]
# ## Run AC-PCA

# %%
def run_acpca(combined_data, confounders):
    ind_vars = list(combined_data.drop(columns=confounders).columns)
    X = combined_data.drop(columns=['Deaths', 'normalized_deaths'], inplace=False)
    X = X.drop(columns=confounders, inplace=False).to_numpy() # 'Density per square mile of land area - Population',
#     print(X.shape)
    X_rows, X_cols = X.shape
    column_names = ['PC' + str(i) for i in range(1, X_cols + 1)]
    
    Y = combined_data.filter(confounders).to_numpy()
    if len(Y.shape) < 2: 
        Y = Y.reshape(len(Y), 1)
    acpca_data, PCs, eigens = ac_pca(X, Y)
    acpca_data = acpca_data.to_numpy()
    PCs = PCs.to_numpy()
    eigens = eigens.to_numpy()
    return acpca_data, PCs, eigens, column_names, ind_vars

# %% [markdown]
# ## Run linear regression on all PCs and get coefficients

# %%
def linreg_coeffs(combined_data, acpca_data, eigens):   
    _, total_pcs = eigens.shape
    pos_pcs = []
    for pc in range(total_pcs): 
        eig = eigens[0,pc]
        if eig > 0: 
            pos_pcs.append(pc)
    if len(pos_pcs) == 0: 
        return 0, 0, pos_pcs
    X = acpca_data[:,pos_pcs]
    Y = combined_data['normalized_deaths']
    reg = lm.LinearRegression().fit(X,Y)
    final_score = reg.score(X,Y)
    coeffs = {}
    for i in range(len(pos_pcs)): 
        coeffs[pos_pcs[i]] = reg.coef_[i]
    return final_score, coeffs, pos_pcs

# %% [markdown]
# ## Calculate individual weight of each variable

# %%
def calc_weights(coeffs, pos_pcs, ind_vars):
    weights = {}
    r,c = PCs.shape
    for pc in pos_pcs: 
        eig = eigens[0, pc]
        PC_dict = {}
        # PC9 = [-0.190896056547888, 0.468236937317933,-0.228567222005448,0.408002822993487,0.0535105125245226,0.407238079363182,0.181820228133276,0.366604933989350,0.435246581102968]
        for i in range(r): 
        #     print('{0:<80} \t {1:>0.3f}'.format(combined_data.columns.values[i+2], PC9[i]))
            loading = PCs[i,pc] # weight of variable in component
            variable = ind_vars[i] # variable name in column headers 
            PC_dict[variable] = loading
            coef = coeffs[pc] # coefficient corresponding to PC
            if variable not in weights:
                weights[variable] = 0
            weights[variable] += coef * loading
    return weights

# %% [markdown]
# ## Print results and identify strongest variable

# %%
def results(weights, final_score):
    print('score:', final_score)
    max_weight = np.max(np.abs(np.array(list(weights.values()))))
    max_var = None
    for var, weight in weights.items():
    #     print('{0:<100} & {1:>0.4f} \\\\ \hline'.format(var.replace('_', '\\_'), weight))
        if abs(weight) == max_weight: 
            max_var = var
            print('*** {0:<100} {1:>0.4f}'.format(var, weight))
        else:
            print('{0:<100} {1:>0.4f}'.format(var, weight))
    print('\n\nmax var: ', max_var)
    return max_var

# %%
confounders = ['baseline']
it = 0 
while len(confounders) < total_vars - 1:
    print('Iteration', it)
    print('confounders:', *confounders)
    it += 1
    acpca_data, PCs, eigens, column_names, ind_vars = run_acpca(combined_data, confounders)
    print(ind_vars)
    final_score, coeffs, pos_pcs = linreg_coeffs(combined_data, acpca_data, eigens)
    if len(pos_pcs) == 0: 
        print('\n\n\n')
        break 
    weights = calc_weights(coeffs, pos_pcs, ind_vars)
    max_var = results(weights, final_score)
    confounders.append(max_var)
    print('\n\n\n')
for c in confounders:
    print(c)
# Out:
# Iteration 0
# confounders: baseline
# ['Density per square mile of land area - Population', 'Rural-urban_Continuum Code_2013', 'Percent of adults with less than a high school diploma 2014-18', "Percent of adults with a bachelor's degree or higher 2014-18", 'Unemployment_rate_2018', 'Med_HH_Income_Percent_of_State_Total_2018', 'Mar Temp AVG / F', 'Apr Temp AVG / F', 'May Temp AVG / F', 'Jun Temp AVG / F', 'Total_age65plus', 'Total households!!Average household size', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school', 'HospCt', 'Deaths', 'normalized_deaths']
# score: 0.5755681328104194
# *** Density per square mile of land area - Population                                                    0.9633
# Rural-urban_Continuum Code_2013                                                                      0.0083
# Percent of adults with less than a high school diploma 2014-18                                       -0.0613
# Percent of adults with a bachelor's degree or higher 2014-18                                         -0.0810
# Unemployment_rate_2018                                                                               0.0062
# Med_HH_Income_Percent_of_State_Total_2018                                                            0.0613
# Mar Temp AVG / F                                                                                     -0.1326
# Apr Temp AVG / F                                                                                     0.3167
# May Temp AVG / F                                                                                     -0.0495
# Jun Temp AVG / F                                                                                     -0.0995
# Total_age65plus                                                                                      0.0847
# Total households!!Average household size                                                             -0.0335
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0351
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0027
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    0.0310
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.1126
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0091
# HospCt                                                                                               0.0513
#
#
# max var:  Density per square mile of land area - Population
#
#
#
#
# Iteration 1
# confounders: baseline Density per square mile of land area - Population
# ['Rural-urban_Continuum Code_2013', 'Percent of adults with less than a high school diploma 2014-18', "Percent of adults with a bachelor's degree or higher 2014-18", 'Unemployment_rate_2018', 'Med_HH_Income_Percent_of_State_Total_2018', 'Mar Temp AVG / F', 'Apr Temp AVG / F', 'May Temp AVG / F', 'Jun Temp AVG / F', 'Total_age65plus', 'Total households!!Average household size', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school', 'HospCt', 'Deaths', 'normalized_deaths']
# score: 0.07579177251357672
# Rural-urban_Continuum Code_2013                                                                      0.0056
# Percent of adults with less than a high school diploma 2014-18                                       0.0032
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0109
# Unemployment_rate_2018                                                                               0.0634
# Med_HH_Income_Percent_of_State_Total_2018                                                            0.0044
# Mar Temp AVG / F                                                                                     -0.1552
# *** Apr Temp AVG / F                                                                                     0.3431
# May Temp AVG / F                                                                                     -0.0398
# Jun Temp AVG / F                                                                                     -0.1184
# Total_age65plus                                                                                      0.0424
# Total households!!Average household size                                                             -0.0580
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0491
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0163
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    0.0041
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0574
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0101
# HospCt                                                                                               0.0373
#
#
# max var:  Apr Temp AVG / F
#
#
#
#
# Iteration 2
# confounders: baseline Density per square mile of land area - Population Apr Temp AVG / F
# ['Rural-urban_Continuum Code_2013', 'Percent of adults with less than a high school diploma 2014-18', "Percent of adults with a bachelor's degree or higher 2014-18", 'Unemployment_rate_2018', 'Med_HH_Income_Percent_of_State_Total_2018', 'Mar Temp AVG / F', 'May Temp AVG / F', 'Jun Temp AVG / F', 'Total_age65plus', 'Total households!!Average household size', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school', 'HospCt', 'Deaths', 'normalized_deaths']
# score: 0.02821008108237344
# Rural-urban_Continuum Code_2013                                                                      0.0052
# Percent of adults with less than a high school diploma 2014-18                                       0.0046
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0222
# *** Unemployment_rate_2018                                                                               0.0691
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0024
# Mar Temp AVG / F                                                                                     -0.0147
# May Temp AVG / F                                                                                     0.0155
# Jun Temp AVG / F                                                                                     -0.0061
# Total_age65plus                                                                                      0.0271
# Total households!!Average household size                                                             -0.0542
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0407
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0144
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0049
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0562
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0180
# HospCt                                                                                               0.0375
#
#
# max var:  Unemployment_rate_2018
#
#
#
#
# Iteration 3
# confounders: baseline Density per square mile of land area - Population Apr Temp AVG / F Unemployment_rate_2018
# ['Rural-urban_Continuum Code_2013', 'Percent of adults with less than a high school diploma 2014-18', "Percent of adults with a bachelor's degree or higher 2014-18", 'Med_HH_Income_Percent_of_State_Total_2018', 'Mar Temp AVG / F', 'May Temp AVG / F', 'Jun Temp AVG / F', 'Total_age65plus', 'Total households!!Average household size', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school', 'HospCt', 'Deaths', 'normalized_deaths']
# score: 0.02257897513153284
# Rural-urban_Continuum Code_2013                                                                      0.0035
# Percent of adults with less than a high school diploma 2014-18                                       0.0133
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0244
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0179
# Mar Temp AVG / F                                                                                     -0.0165
# May Temp AVG / F                                                                                     0.0212
# Jun Temp AVG / F                                                                                     -0.0106
# Total_age65plus                                                                                      0.0492
# *** Total households!!Average household size                                                             -0.0528
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0425
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0137
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    0.0146
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0481
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0123
# HospCt                                                                                               0.0346
#
#
# max var:  Total households!!Average household size
#
#
#
#
# Iteration 4
# confounders: baseline Density per square mile of land area - Population Apr Temp AVG / F Unemployment_rate_2018 Total households!!Average household size
# ['Rural-urban_Continuum Code_2013', 'Percent of adults with less than a high school diploma 2014-18', "Percent of adults with a bachelor's degree or higher 2014-18", 'Med_HH_Income_Percent_of_State_Total_2018', 'Mar Temp AVG / F', 'May Temp AVG / F', 'Jun Temp AVG / F', 'Total_age65plus', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school', 'HospCt', 'Deaths', 'normalized_deaths']
# score: 0.019017027894767446
# Rural-urban_Continuum Code_2013                                                                      0.0049
# Percent of adults with less than a high school diploma 2014-18                                       -0.0021
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0288
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0219
# Mar Temp AVG / F                                                                                     -0.0191
# May Temp AVG / F                                                                                     0.0282
# Jun Temp AVG / F                                                                                     -0.0164
# *** Total_age65plus                                                                                      0.0479
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0422
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0133
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    0.0069
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0308
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0182
# HospCt                                                                                               0.0365
#
#
# max var:  Total_age65plus
#
#
#
#
# Iteration 5
# confounders: baseline Density per square mile of land area - Population Apr Temp AVG / F Unemployment_rate_2018 Total households!!Average household size Total_age65plus
# ['Rural-urban_Continuum Code_2013', 'Percent of adults with less than a high school diploma 2014-18', "Percent of adults with a bachelor's degree or higher 2014-18", 'Med_HH_Income_Percent_of_State_Total_2018', 'Mar Temp AVG / F', 'May Temp AVG / F', 'Jun Temp AVG / F', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school', 'HospCt', 'Deaths', 'normalized_deaths']
# score: 0.029449334630788138
# Rural-urban_Continuum Code_2013                                                                      -0.0089
# Percent of adults with less than a high school diploma 2014-18                                       0.0058
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0288
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0268
# Mar Temp AVG / F                                                                                     -0.0063
# May Temp AVG / F                                                                                     -0.0151
# Jun Temp AVG / F                                                                                     0.0214
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0512
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0187
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0208
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0268
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0394
# *** HospCt                                                                                               0.0816
#
#
# max var:  HospCt
#
#
#
#
# Iteration 6
# confounders: baseline Density per square mile of land area - Population Apr Temp AVG / F Unemployment_rate_2018 Total households!!Average household size Total_age65plus HospCt
# ['Rural-urban_Continuum Code_2013', 'Percent of adults with less than a high school diploma 2014-18', "Percent of adults with a bachelor's degree or higher 2014-18", 'Med_HH_Income_Percent_of_State_Total_2018', 'Mar Temp AVG / F', 'May Temp AVG / F', 'Jun Temp AVG / F', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school', 'Deaths', 'normalized_deaths']
# score: 0.01735190304260581
# Rural-urban_Continuum Code_2013                                                                      0.0147
# Percent of adults with less than a high school diploma 2014-18                                       -0.0053
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0117
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0182
# Mar Temp AVG / F                                                                                     -0.0127
# May Temp AVG / F                                                                                     0.0057
# Jun Temp AVG / F                                                                                     0.0052
# *** SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0576
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      0.0005
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0151
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0100
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0360
#
#
# max var:  SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool
#
#
#
#
# Iteration 7
# confounders: baseline Density per square mile of land area - Population Apr Temp AVG / F Unemployment_rate_2018 Total households!!Average household size Total_age65plus HospCt SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool
# ['Rural-urban_Continuum Code_2013', 'Percent of adults with less than a high school diploma 2014-18', "Percent of adults with a bachelor's degree or higher 2014-18", 'Med_HH_Income_Percent_of_State_Total_2018', 'Mar Temp AVG / F', 'May Temp AVG / F', 'Jun Temp AVG / F', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school', 'Deaths', 'normalized_deaths']
# score: 4.938108046970146e-05
# Rural-urban_Continuum Code_2013                                                                      -0.0008
# Percent of adults with less than a high school diploma 2014-18                                       -0.0001
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0008
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0020
# Mar Temp AVG / F                                                                                     0.0025
# May Temp AVG / F                                                                                     -0.0003
# *** Jun Temp AVG / F                                                                                     -0.0028
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      0.0022
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0022
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0013
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0012
#
#
# max var:  Jun Temp AVG / F
#
#
#
#
# Iteration 8
# confounders: baseline Density per square mile of land area - Population Apr Temp AVG / F Unemployment_rate_2018 Total households!!Average household size Total_age65plus HospCt SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool Jun Temp AVG / F
# ['Rural-urban_Continuum Code_2013', 'Percent of adults with less than a high school diploma 2014-18', "Percent of adults with a bachelor's degree or higher 2014-18", 'Med_HH_Income_Percent_of_State_Total_2018', 'Mar Temp AVG / F', 'May Temp AVG / F', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school', 'Deaths', 'normalized_deaths']
# score: 2.068540984456746e-05
# Rural-urban_Continuum Code_2013                                                                      -0.0007
# Percent of adults with less than a high school diploma 2014-18                                       0.0002
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0002
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0010
# Mar Temp AVG / F                                                                                     -0.0000
# May Temp AVG / F                                                                                     0.0000
# *** SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      0.0020
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0019
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0008
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0004
#
#
# max var:  SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten
#
#
#
#
# Iteration 9
# confounders: baseline Density per square mile of land area - Population Apr Temp AVG / F Unemployment_rate_2018 Total households!!Average household size Total_age65plus HospCt SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool Jun Temp AVG / F SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten
# ['Rural-urban_Continuum Code_2013', 'Percent of adults with less than a high school diploma 2014-18', "Percent of adults with a bachelor's degree or higher 2014-18", 'Med_HH_Income_Percent_of_State_Total_2018', 'Mar Temp AVG / F', 'May Temp AVG / F', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school', 'Deaths', 'normalized_deaths']
# score: 1.634361120883554e-07
# Rural-urban_Continuum Code_2013                                                                      -0.0001
# Percent of adults with less than a high school diploma 2014-18                                       -0.0000
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0000
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0001
# Mar Temp AVG / F                                                                                     0.0000
# May Temp AVG / F                                                                                     -0.0000
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    0.0002
# *** SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         -0.0002
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0001
#
#
# max var:  SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)
#
#
#
#
# Iteration 10
# confounders: baseline Density per square mile of land area - Population Apr Temp AVG / F Unemployment_rate_2018 Total households!!Average household size Total_age65plus HospCt SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool Jun Temp AVG / F SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)
# ['Rural-urban_Continuum Code_2013', 'Percent of adults with less than a high school diploma 2014-18', "Percent of adults with a bachelor's degree or higher 2014-18", 'Med_HH_Income_Percent_of_State_Total_2018', 'Mar Temp AVG / F', 'May Temp AVG / F', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)', 'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school', 'Deaths', 'normalized_deaths']
#
#
#
#
# baseline
# Density per square mile of land area - Population
# Apr Temp AVG / F
# Unemployment_rate_2018
# Total households!!Average household size
# Total_age65plus
# HospCt
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool
# Jun Temp AVG / F
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)
