# %% [raw]
# Beatriz Medeiros
# Notebook for AC-PCA on independent and dependent variables separately

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.linear_model as lm
from collections import defaultdict
import sys; sys.path.append('../')
from src.data_analysis.tools import ac_pca

# %% [markdown]
# ## Get Preprocessed data

# %%
combined_data = pd.read_csv('../data/intermediates/pre_acpca1.csv')
# combined_data = combined_data.drop(columns='Total_age65plus')
# combined_data = combined_data.drop(columns='HospCt')
combined_data.set_index('FIPS', inplace=True)
print(combined_data.shape)
ind_vars = list(combined_data.columns)
total_vars = len(ind_vars)
combined_data.head()
# Out:
# (450, 27)
#       2wk Prior Mobility  2wk Onset Mobility  2wk Post Mobility  \
# FIPS
# 1003            0.459962            0.738688           0.824197
# 1051            0.521206            0.785409           0.844992
# 1073            0.581889            0.834773           0.879697
# 1081            0.301939            0.575735           0.703762
# 1089            0.492726            0.741843           0.824973
#
#       inter_movement  out_movement  baseline m50 mobility  \
# FIPS
# 1003        0.519349      0.327736               0.663421
# 1051        0.452205      1.000000               0.913574
# 1073        0.775948      0.255409               0.526105
# 1081        0.572121      0.624091               0.334816
# 1089        0.686220      0.197095               0.553652
#
#       Density per square mile of land area - Population  \
# FIPS
# 1003                                           0.001558
# 1051                                           0.001753
# 1073                                           0.008438
# 1081                                           0.003231
# 1089                                           0.005921
#
#       Rural-urban_Continuum Code_2013  \
# FIPS
# 1003                              0.4
# 1051                              0.2
# 1073                              0.0
# 1081                              0.4
# 1089                              0.2
#
#       Percent of adults with less than a high school diploma 2014-18  \
# FIPS
# 1003                                           0.229851
# 1051                                           0.346269
# 1073                                           0.247761
# 1081                                           0.223881
# 1089                                           0.205970
#
#       Percent of adults with a bachelor's degree or higher 2014-18  ...  \
# FIPS                                                                ...
# 1003                                           0.312698             ...
# 1051                                           0.204762             ...
# 1073                                           0.330159             ...
# 1081                                           0.357143             ...
# 1089                                           0.477778             ...
#
#       SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)  \
# FIPS
# 1003                                           0.500894
# 1051                                           0.710722
# 1073                                           0.448229
# 1081                                           0.477880
# 1089                                           0.524713
#
#       SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school  \
# FIPS
# 1003                                           0.023750
# 1051                                           0.104400
# 1073                                           0.166735
# 1081                                           0.634204
# 1089                                           0.251270
#
#         HospCt  Longterm HospCt  Hispanic Population  Black Population  \
# FIPS
# 1003  0.207274         0.000000             0.038549          0.116048
# 1051  0.367907         0.000000             0.021248          0.289589
# 1073  0.205628         0.114238             0.031499          0.594616
# 1081  0.091883         0.000000             0.029159          0.312223
# 1089  0.123296         0.000000             0.043017          0.337374
#
#       Outbreak Month Temp AVG / F  Time from outbreak to intervention  \
# FIPS
# 1003                     0.754826                              0.4625
# 1051                     0.928571                              0.3125
# 1073                     0.698842                              0.6750
# 1081                     0.708494                              0.6500
# 1089                     0.666023                              0.5750
#
#         Deaths  normalized_deaths
# FIPS
# 1003  0.000591           0.006585
# 1051  0.000788           0.025222
# 1073  0.005518           0.012855
# 1081  0.003745           0.040884
# 1089  0.000197           0.001246
#
# [5 rows x 27 columns]

# %%
ind_vars
# Out:
# ['2wk Prior Mobility',
#  '2wk Onset Mobility',
#  '2wk Post Mobility',
#  'inter_movement',
#  'out_movement',
#  'baseline m50 mobility',
#  'Density per square mile of land area - Population',
#  'Rural-urban_Continuum Code_2013',
#  'Percent of adults with less than a high school diploma 2014-18',
#  "Percent of adults with a bachelor's degree or higher 2014-18",
#  'Unemployment_rate_2018',
#  'Med_HH_Income_Percent_of_State_Total_2018',
#  'Total_age65plus',
#  'Total households!!Average household size',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school',
#  'HospCt',
#  'Longterm HospCt',
#  'Hispanic Population',
#  'Black Population',
#  'Outbreak Month Temp AVG / F',
#  'Time from outbreak to intervention',
#  'Deaths',
#  'normalized_deaths']

# %% [markdown]
# ## Run AC-PCA

# %%
def run_acpca(combined_data, confounders):
    ind_vars = list(combined_data.drop(columns=confounders).columns)
    X = combined_data.drop(columns=['Deaths', 'normalized_deaths'], inplace=False)
    X = X.drop(columns=confounders, inplace=False).to_numpy() # 'Density per square mile of land area - Population',
#     print(X.shape)
    X_rows, X_cols = X.shape
    column_names = ['PC' + str(i) for i in range(1, X_cols + 1)]
    if len(confounders) > 0: 
        Y = combined_data.filter(confounders).to_numpy()
    else: 
        Y = np.zeros((X_rows))
    if len(Y.shape) < 2: 
        Y = Y.reshape(len(Y), 1)
    acpca_data, PCs, eigens = ac_pca(X, Y)
    acpca_data = acpca_data.to_numpy()
    PCs = PCs.to_numpy()
    eigens = eigens.to_numpy()
    return acpca_data, PCs, eigens, column_names, ind_vars

# %% [markdown]
# ## Run linear regression on all PCs and get coefficients

# %%
def linreg_coeffs(combined_data, acpca_data, eigens):   
    _, total_pcs = eigens.shape
    pos_pcs = []
    for pc in range(total_pcs): 
        eig = eigens[0,pc]
        if eig > 0: 
            pos_pcs.append(pc)
    if len(pos_pcs) == 0: 
        return 0, 0, pos_pcs
    X = acpca_data[:,pos_pcs]
    Y = combined_data['normalized_deaths']
    reg = lm.LinearRegression().fit(X,Y)
    final_score = reg.score(X,Y)
    coeffs = {}
    for i in range(len(pos_pcs)): 
        coeffs[pos_pcs[i]] = reg.coef_[i]
    return final_score, coeffs, pos_pcs

# %% [markdown]
# ## Calculate individual weight of each variable

# %%
def calc_weights(coeffs, pos_pcs, ind_vars):
    weights = {}
    r,c = PCs.shape
    for pc in pos_pcs: 
        eig = eigens[0, pc]
        PC_dict = {}
        # PC9 = [-0.190896056547888, 0.468236937317933,-0.228567222005448,0.408002822993487,0.0535105125245226,0.407238079363182,0.181820228133276,0.366604933989350,0.435246581102968]
        for i in range(r): 
        #     print('{0:<80} \t {1:>0.3f}'.format(combined_data.columns.values[i+2], PC9[i]))
            loading = PCs[i,pc] # weight of variable in component
            variable = ind_vars[i] # variable name in column headers 
            PC_dict[variable] = loading
            coef = coeffs[pc] # coefficient corresponding to PC
            if variable not in weights:
                weights[variable] = 0
            weights[variable] += coef * loading
    return weights

# %% [markdown]
# ## Print results and identify strongest variable

# %%
def results(weights, final_score, mobility_features):
    print('score:', final_score)
    max_weight_mag = np.max(np.abs(np.array(list(weights.values()))))
    max_weight = 0
    max_var = None
    max_mobility_weight = 0
    max_mobility_var = None
    for var, weight in weights.items():
        if var in mobility_features and weight > max_mobility_weight:
            max_mobility_weight = weight
            max_mobility_var = var
    #     print('{0:<100} & {1:>0.4f} \\\\ \hline'.format(var.replace('_', '\\_'), weight))
        if abs(weight) == max_weight_mag: 
            max_weight = weight
            max_var = var
            print('*** {0:<100} {1:>0.4f}'.format(var, weight))
        else:
            print('{0:<100} {1:>0.4f}'.format(var, weight))
    print('\n\nmax var: ', max_var)
    return max_var, max_weight, max_mobility_var, max_mobility_weight

# %%
mobility_features = ['inter_movement', 'out_movement', 'baseline m50 mobility']
confounders = {} 
it = 0 
while len(confounders) < total_vars - 1:
    print('Iteration', it)
    print('confounders:', *confounders.keys())
    it += 1
    acpca_data, PCs, eigens, column_names, ind_vars = run_acpca(combined_data, confounders)
    final_score, coeffs, pos_pcs = linreg_coeffs(combined_data, acpca_data, eigens)
    if len(pos_pcs) == 0: 
        print('\n\n\n')
        break 
    weights = calc_weights(coeffs, pos_pcs, ind_vars)
    max_var, max_weight, max_mobility_var, max_mobility_weight = results(weights, final_score, mobility_features)
    confounders[max_var] = max_weight
    print('\n\n\n')
for var, weight in confounders.items():
    print('{0:<100} & {1:>0.4f} \\\\hline'.format(var, weight))
# Out:
# Iteration 0
# confounders:
# score: 0.7073526431007172
# 2wk Prior Mobility                                                                                   0.0122
# 2wk Onset Mobility                                                                                   0.0410
# 2wk Post Mobility                                                                                    -0.0534
# inter_movement                                                                                       0.0257
# out_movement                                                                                         0.0690
# baseline m50 mobility                                                                                0.0367
# *** Density per square mile of land area - Population                                                    0.9494
# Rural-urban_Continuum Code_2013                                                                      0.0577
# Percent of adults with less than a high school diploma 2014-18                                       -0.0010
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0183
# Unemployment_rate_2018                                                                               0.0323
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0480
# Total_age65plus                                                                                      0.2095
# Total households!!Average household size                                                             0.0254
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0430
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      0.0124
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    0.0603
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0387
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0544
# HospCt                                                                                               0.0364
# Longterm HospCt                                                                                      -0.0170
# Hispanic Population                                                                                  -0.0096
# Black Population                                                                                     0.0308
# Outbreak Month Temp AVG / F                                                                          -0.0679
# Time from outbreak to intervention                                                                   0.0209
#
#
# max var:  Density per square mile of land area - Population
#
#
#
#
# Iteration 1
# confounders: Density per square mile of land area - Population
# score: 0.13866095203847406
# 2wk Prior Mobility                                                                                   0.0212
# 2wk Onset Mobility                                                                                   0.0535
# 2wk Post Mobility                                                                                    -0.0685
# inter_movement                                                                                       0.0186
# out_movement                                                                                         0.0766
# baseline m50 mobility                                                                                0.0199
# Rural-urban_Continuum Code_2013                                                                      0.0485
# Percent of adults with less than a high school diploma 2014-18                                       0.0167
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0403
# Unemployment_rate_2018                                                                               0.0313
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0436
# *** Total_age65plus                                                                                      0.1896
# Total households!!Average household size                                                             0.0177
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0430
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      0.0056
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    0.0429
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0263
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0468
# HospCt                                                                                               0.0380
# Longterm HospCt                                                                                      -0.0179
# Hispanic Population                                                                                  -0.0064
# Black Population                                                                                     0.0345
# Outbreak Month Temp AVG / F                                                                          -0.0721
# Time from outbreak to intervention                                                                   0.0307
#
#
# max var:  Total_age65plus
#
#
#
#
# Iteration 2
# confounders: Density per square mile of land area - Population Total_age65plus
# score: 0.11313807127310761
# 2wk Prior Mobility                                                                                   0.0248
# 2wk Onset Mobility                                                                                   0.0030
# 2wk Post Mobility                                                                                    -0.0282
# inter_movement                                                                                       0.0146
# out_movement                                                                                         0.0597
# baseline m50 mobility                                                                                0.0258
# *** Rural-urban_Continuum Code_2013                                                                      0.0652
# Percent of adults with less than a high school diploma 2014-18                                       -0.0193
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0191
# Unemployment_rate_2018                                                                               0.0508
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0527
# Total households!!Average household size                                                             0.0252
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0324
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0095
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0360
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0308
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0094
# HospCt                                                                                               0.0403
# Longterm HospCt                                                                                      -0.0148
# Hispanic Population                                                                                  -0.0078
# Black Population                                                                                     0.0166
# Outbreak Month Temp AVG / F                                                                          -0.0505
# Time from outbreak to intervention                                                                   0.0371
#
#
# max var:  Rural-urban_Continuum Code_2013
#
#
#
#
# Iteration 3
# confounders: Density per square mile of land area - Population Total_age65plus Rural-urban_Continuum Code_2013
# score: 0.08999054365874293
# 2wk Prior Mobility                                                                                   0.0225
# 2wk Onset Mobility                                                                                   -0.0126
# 2wk Post Mobility                                                                                    -0.0128
# inter_movement                                                                                       0.0075
# out_movement                                                                                         0.0386
# baseline m50 mobility                                                                                0.0187
# Percent of adults with less than a high school diploma 2014-18                                       -0.0121
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0022
# *** Unemployment_rate_2018                                                                               0.0647
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0635
# Total households!!Average household size                                                             0.0252
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0333
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0070
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0452
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0359
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0098
# HospCt                                                                                               0.0576
# Longterm HospCt                                                                                      -0.0087
# Hispanic Population                                                                                  -0.0303
# Black Population                                                                                     0.0027
# Outbreak Month Temp AVG / F                                                                          -0.0440
# Time from outbreak to intervention                                                                   0.0234
#
#
# max var:  Unemployment_rate_2018
#
#
#
#
# Iteration 4
# confounders: Density per square mile of land area - Population Total_age65plus Rural-urban_Continuum Code_2013 Unemployment_rate_2018
# score: 0.08276921247680526
# 2wk Prior Mobility                                                                                   0.0215
# 2wk Onset Mobility                                                                                   -0.0092
# 2wk Post Mobility                                                                                    -0.0140
# inter_movement                                                                                       0.0022
# out_movement                                                                                         0.0342
# baseline m50 mobility                                                                                0.0152
# Percent of adults with less than a high school diploma 2014-18                                       -0.0027
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0006
# *** Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0655
# Total households!!Average household size                                                             0.0239
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0339
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0064
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0446
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0373
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0078
# HospCt                                                                                               0.0637
# Longterm HospCt                                                                                      -0.0072
# Hispanic Population                                                                                  -0.0396
# Black Population                                                                                     -0.0018
# Outbreak Month Temp AVG / F                                                                          -0.0429
# Time from outbreak to intervention                                                                   0.0200
#
#
# max var:  Med_HH_Income_Percent_of_State_Total_2018
#
#
#
#
# Iteration 5
# confounders: Density per square mile of land area - Population Total_age65plus Rural-urban_Continuum Code_2013 Unemployment_rate_2018 Med_HH_Income_Percent_of_State_Total_2018
# score: 0.07258934122926675
# 2wk Prior Mobility                                                                                   0.0217
# 2wk Onset Mobility                                                                                   -0.0334
# 2wk Post Mobility                                                                                    0.0043
# inter_movement                                                                                       -0.0059
# out_movement                                                                                         0.0279
# baseline m50 mobility                                                                                0.0017
# Percent of adults with less than a high school diploma 2014-18                                       0.0053
# Percent of adults with a bachelor's degree or higher 2014-18                                         -0.0401
# Total households!!Average household size                                                             0.0084
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0341
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0101
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0472
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0383
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0009
# *** HospCt                                                                                               0.0644
# Longterm HospCt                                                                                      -0.0056
# Hispanic Population                                                                                  -0.0253
# Black Population                                                                                     0.0021
# Outbreak Month Temp AVG / F                                                                          -0.0454
# Time from outbreak to intervention                                                                   0.0108
#
#
# max var:  HospCt
#
#
#
#
# Iteration 6
# confounders: Density per square mile of land area - Population Total_age65plus Rural-urban_Continuum Code_2013 Unemployment_rate_2018 Med_HH_Income_Percent_of_State_Total_2018 HospCt
# score: 0.06048689262864104
# 2wk Prior Mobility                                                                                   0.0325
# 2wk Onset Mobility                                                                                   -0.0353
# 2wk Post Mobility                                                                                    0.0122
# inter_movement                                                                                       -0.0223
# out_movement                                                                                         0.0201
# baseline m50 mobility                                                                                -0.0052
# Percent of adults with less than a high school diploma 2014-18                                       0.0239
# Percent of adults with a bachelor's degree or higher 2014-18                                         -0.0384
# Total households!!Average household size                                                             -0.0001
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0371
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0058
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0435
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0383
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0042
# Longterm HospCt                                                                                      -0.0060
# *** Hispanic Population                                                                                  -0.0456
# Black Population                                                                                     -0.0054
# Outbreak Month Temp AVG / F                                                                          -0.0406
# Time from outbreak to intervention                                                                   0.0014
#
#
# max var:  Hispanic Population
#
#
#
#
# Iteration 7
# confounders: Density per square mile of land area - Population Total_age65plus Rural-urban_Continuum Code_2013 Unemployment_rate_2018 Med_HH_Income_Percent_of_State_Total_2018 HospCt Hispanic Population
# score: 0.037949513412263824
# 2wk Prior Mobility                                                                                   0.0315
# *** 2wk Onset Mobility                                                                                   -0.0825
# 2wk Post Mobility                                                                                    0.0441
# inter_movement                                                                                       0.0193
# out_movement                                                                                         0.0247
# baseline m50 mobility                                                                                0.0063
# Percent of adults with less than a high school diploma 2014-18                                       0.0297
# Percent of adults with a bachelor's degree or higher 2014-18                                         -0.0207
# Total households!!Average household size                                                             -0.0095
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0312
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      0.0071
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0484
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0238
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0064
# Longterm HospCt                                                                                      0.0104
# Black Population                                                                                     -0.0258
# Outbreak Month Temp AVG / F                                                                          -0.0358
# Time from outbreak to intervention                                                                   -0.0206
#
#
# max var:  2wk Onset Mobility
#
#
#
#
# Iteration 8
# confounders: Density per square mile of land area - Population Total_age65plus Rural-urban_Continuum Code_2013 Unemployment_rate_2018 Med_HH_Income_Percent_of_State_Total_2018 HospCt Hispanic Population 2wk Onset Mobility
# score: 0.03280962160349521
# 2wk Prior Mobility                                                                                   0.0085
# 2wk Post Mobility                                                                                    -0.0020
# inter_movement                                                                                       0.0262
# out_movement                                                                                         0.0231
# baseline m50 mobility                                                                                0.0084
# Percent of adults with less than a high school diploma 2014-18                                       0.0214
# Percent of adults with a bachelor's degree or higher 2014-18                                         -0.0209
# Total households!!Average household size                                                             -0.0071
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0344
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      0.0095
# *** SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0500
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0197
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0090
# Longterm HospCt                                                                                      -0.0066
# Black Population                                                                                     -0.0249
# Outbreak Month Temp AVG / F                                                                          -0.0362
# Time from outbreak to intervention                                                                   -0.0168
#
#
# max var:  SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)
#
#
#
#
# Iteration 9
# confounders: Density per square mile of land area - Population Total_age65plus Rural-urban_Continuum Code_2013 Unemployment_rate_2018 Med_HH_Income_Percent_of_State_Total_2018 HospCt Hispanic Population 2wk Onset Mobility SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)
# score: 0.02460384142047889
# 2wk Prior Mobility                                                                                   0.0167
# 2wk Post Mobility                                                                                    0.0004
# inter_movement                                                                                       0.0023
# out_movement                                                                                         0.0153
# baseline m50 mobility                                                                                0.0139
# Percent of adults with less than a high school diploma 2014-18                                       0.0178
# Percent of adults with a bachelor's degree or higher 2014-18                                         -0.0149
# Total households!!Average household size                                                             -0.0291
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0212
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0067
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0030
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0133
# Longterm HospCt                                                                                      0.0077
# *** Black Population                                                                                     -0.0399
# Outbreak Month Temp AVG / F                                                                          -0.0201
# Time from outbreak to intervention                                                                   0.0115
#
#
# max var:  Black Population
#
#
#
#
# Iteration 10
# confounders: Density per square mile of land area - Population Total_age65plus Rural-urban_Continuum Code_2013 Unemployment_rate_2018 Med_HH_Income_Percent_of_State_Total_2018 HospCt Hispanic Population 2wk Onset Mobility SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8) Black Population
# score: 0.0024703423029921456
# 2wk Prior Mobility                                                                                   -0.0049
# 2wk Post Mobility                                                                                    -0.0014
# inter_movement                                                                                       -0.0094
# out_movement                                                                                         -0.0156
# *** baseline m50 mobility                                                                                0.0197
# Percent of adults with less than a high school diploma 2014-18                                       0.0170
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0033
# Total households!!Average household size                                                             -0.0111
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0159
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0046
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         -0.0046
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0017
# Longterm HospCt                                                                                      -0.0005
# Outbreak Month Temp AVG / F                                                                          -0.0060
# Time from outbreak to intervention                                                                   -0.0014
#
#
# max var:  baseline m50 mobility
#
#
#
#
# Iteration 11
# confounders: Density per square mile of land area - Population Total_age65plus Rural-urban_Continuum Code_2013 Unemployment_rate_2018 Med_HH_Income_Percent_of_State_Total_2018 HospCt Hispanic Population 2wk Onset Mobility SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8) Black Population baseline m50 mobility
# score: 0.002054995305913798
# 2wk Prior Mobility                                                                                   -0.0120
# 2wk Post Mobility                                                                                    -0.0032
# *** inter_movement                                                                                       0.0195
# out_movement                                                                                         0.0051
# Percent of adults with less than a high school diploma 2014-18                                       0.0051
# Percent of adults with a bachelor's degree or higher 2014-18                                         -0.0064
# Total households!!Average household size                                                             -0.0077
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0147
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0026
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         -0.0070
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0076
# Longterm HospCt                                                                                      -0.0107
# Outbreak Month Temp AVG / F                                                                          0.0001
# Time from outbreak to intervention                                                                   -0.0018
#
#
# max var:  inter_movement
#
#
#
#
# Iteration 12
# confounders: Density per square mile of land area - Population Total_age65plus Rural-urban_Continuum Code_2013 Unemployment_rate_2018 Med_HH_Income_Percent_of_State_Total_2018 HospCt Hispanic Population 2wk Onset Mobility SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8) Black Population baseline m50 mobility inter_movement
# score: 0.001064707629264805
# 2wk Prior Mobility                                                                                   -0.0006
# 2wk Post Mobility                                                                                    0.0042
# out_movement                                                                                         0.0015
# Percent of adults with less than a high school diploma 2014-18                                       0.0010
# Percent of adults with a bachelor's degree or higher 2014-18                                         -0.0014
# Total households!!Average household size                                                             0.0046
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0070
# *** SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0145
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         -0.0008
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0023
# Longterm HospCt                                                                                      0.0026
# Outbreak Month Temp AVG / F                                                                          -0.0014
# Time from outbreak to intervention                                                                   -0.0044
#
#
# max var:  SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten
#
#
#
#
# Iteration 13
# confounders: Density per square mile of land area - Population Total_age65plus Rural-urban_Continuum Code_2013 Unemployment_rate_2018 Med_HH_Income_Percent_of_State_Total_2018 HospCt Hispanic Population 2wk Onset Mobility SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8) Black Population baseline m50 mobility inter_movement SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten
# score: 6.0668932231666695e-05
# 2wk Prior Mobility                                                                                   0.0014
# 2wk Post Mobility                                                                                    -0.0003
# out_movement                                                                                         0.0007
# Percent of adults with less than a high school diploma 2014-18                                       -0.0017
# Percent of adults with a bachelor's degree or higher 2014-18                                         -0.0009
# *** Total households!!Average household size                                                             0.0047
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0009
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         -0.0036
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0006
# Longterm HospCt                                                                                      0.0005
# Outbreak Month Temp AVG / F                                                                          -0.0006
# Time from outbreak to intervention                                                                   -0.0012
#
#
# max var:  Total households!!Average household size
#
#
#
#
# Iteration 14
# confounders: Density per square mile of land area - Population Total_age65plus Rural-urban_Continuum Code_2013 Unemployment_rate_2018 Med_HH_Income_Percent_of_State_Total_2018 HospCt Hispanic Population 2wk Onset Mobility SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8) Black Population baseline m50 mobility inter_movement SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten Total households!!Average household size
#
#
#
#
# Density per square mile of land area - Population                                                    & 0.9494 \\hline
# Total_age65plus                                                                                      & 0.1896 \\hline
# Rural-urban_Continuum Code_2013                                                                      & 0.0652 \\hline
# Unemployment_rate_2018                                                                               & 0.0647 \\hline
# Med_HH_Income_Percent_of_State_Total_2018                                                            & -0.0655 \\hline
# HospCt                                                                                               & 0.0644 \\hline
# Hispanic Population                                                                                  & -0.0456 \\hline
# 2wk Onset Mobility                                                                                   & -0.0825 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    & -0.0500 \\hline
# Black Population                                                                                     & -0.0399 \\hline
# baseline m50 mobility                                                                                & 0.0197 \\hline
# inter_movement                                                                                       & 0.0195 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      & -0.0145 \\hline
# Total households!!Average household size                                                             & 0.0047 \\hline

# %% [raw]
# problems: 2wk mobility averages and time from outbreak to intervention should all be positive

# %% [raw]
# interventon date - outbreak
# neg if intervention happens before outbreak (neg in most cases)
# pos if outbreak before intervention
# 0 if same day

# %% [raw]
# Density per square mile of land area - Population                                                    & 0.9555 \\hline
# Total_age65plus                                                                                      & 0.1959 \\hline
# Outbreak Month Temp AVG / F                                                                          & -0.0657 \\hline
# 2wk Onset Mobility                                                                                   & -0.0979 \\hline
# Med_HH_Income_Percent_of_State_Total_2018                                                            & -0.0781 \\hline
# Unemployment_rate_2018                                                                               & 0.0741 \\hline
# out_movement                                                                                         & 0.0518 \\hline
# HospCt                                                                                               & 0.0385 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          & 0.0370 \\hline
# 2wk Prior Mobility                                                                                   & 0.0398 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         & 0.0259 \\hline
# Time from outbreak to intervention                                                                   & -0.0179 \\hline
# Rural-urban_Continuum Code_2013                                                                      & 0.0084 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      & 0.0095 \\hline

# %% [raw]
# After fixing intervention to be school closing, Longterm still negative
#
# Density per square mile of land area - Population                                                    & 0.9494 \\hline
# Total_age65plus                                                                                      & 0.1896 \\hline
# Rural-urban_Continuum Code_2013                                                                      & 0.0652 \\hline
# Unemployment_rate_2018                                                                               & 0.0647 \\hline
# Med_HH_Income_Percent_of_State_Total_2018                                                            & -0.0655 \\hline
# HospCt                                                                                               & 0.0644 \\hline
# Hispanic Population                                                                                  & -0.0456 \\hline
# 2wk Onset Mobility                                                                                   & -0.0825 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    & -0.0500 \\hline
# Black Population                                                                                     & -0.0399 \\hline
# baseline m50 mobility                                                                                & 0.0197 \\hline
# inter_movement                                                                                       & 0.0195 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      & -0.0145 \\hline
# Total households!!Average household size                                                             & 0.0047 \\hline

# %% [raw]
# W/o age 65+ and w/o HospCt but w/o fixing intervention to be school closing
#
# Density per square mile of land area - Population                                                    & 0.9183 \\hline
# Outbreak Month Temp AVG / F                                                                          & -0.0678 \\hline
# 2wk Onset Mobility                                                                                   & -0.0996 \\hline
# Med_HH_Income_Percent_of_State_Total_2018                                                            & -0.0760 \\hline
# Unemployment_rate_2018                                                                               & 0.0744 \\hline
# out_movement                                                                                         & 0.0534 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         & 0.0378 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          & 0.0366 \\hline
# 2wk Prior Mobility                                                                                   & 0.0326 \\hline
# Hispanic Population                                                                                  & -0.0246 \\hline
# Total households!!Average household size                                                             & -0.0479 \\hline
# Longterm HospCt                                                                                      & -0.0231 \\hline
# Time from outbreak to intervention                                                                   & -0.0189 \\hline

# %% [raw]
# W/o age 65+ and w/o HospCt after fixing intervention to be school closing
#
# Density per square mile of land area - Population                                                    & 0.9120 \\hline
# Rural-urban_Continuum Code_2013                                                                      & 0.0701 \\hline
# Unemployment_rate_2018                                                                               & 0.0622 \\hline
# Hispanic Population                                                                                  & -0.0603 \\hline
# Med_HH_Income_Percent_of_State_Total_2018                                                            & -0.0555 \\hline
# 2wk Onset Mobility                                                                                   & -0.0540 \\hline
# Outbreak Month Temp AVG / F                                                                          & -0.0392 \\hline
# Total households!!Average household size                                                             & -0.0444 \\hline
# out_movement                                                                                         & 0.0566 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    & -0.0427 \\hline
# Longterm HospCt                                                                                      & 0.0224 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          & 0.0229 \\hline
# 2wk Prior Mobility                                                                                   & 0.1008 \\hline

# %% [raw]
# W/o age 65+ after fixing intervention to be school closing, Longterm HospCt is negative but does not come out as significant variable
#
# Density per square mile of land area - Population                                                    & 0.9096 \\hline
# Rural-urban_Continuum Code_2013                                                                      & 0.0645 \\hline
# Med_HH_Income_Percent_of_State_Total_2018                                                            & -0.0619 \\hline
# Unemployment_rate_2018                                                                               & 0.0671 \\hline
# HospCt                                                                                               & 0.0655 \\hline
# Hispanic Population                                                                                  & -0.0480 \\hline
# 2wk Onset Mobility                                                                                   & -0.0610 \\hline
# Outbreak Month Temp AVG / F                                                                          & -0.0379 \\hline
# Total households!!Average household size                                                             & -0.0399 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    & -0.0500 \\hline
# out_movement                                                                                         & 0.0444 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          & 0.0184 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      & -0.0114 \\hline
# 2wk Prior Mobility                                                                                   & 0.0946 \\hline

# %% [raw]
# w/o HospCt after fixing intervention to be school closing
#
# Density per square mile of land area - Population                                                    & 0.9520 \\hline
# Total_age65plus                                                                                      & 0.1906 \\hline
# Rural-urban_Continuum Code_2013                                                                      & 0.0708 \\hline
# Unemployment_rate_2018                                                                               & 0.0650 \\hline
# Med_HH_Income_Percent_of_State_Total_2018                                                            & -0.0618 \\hline
# Hispanic Population                                                                                  & -0.0479 \\hline
# 2wk Onset Mobility                                                                                   & -0.0790 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    & -0.0521 \\hline
# Black Population                                                                                     & -0.0400 \\hline
# baseline m50 mobility                                                                                & 0.0257 \\hline
# Longterm HospCt                                                                                      & 0.0223 \\hline
# inter_movement                                                                                       & 0.0157 \\hline
# Total households!!Average household size                                                             & 0.0099 \\hline

# %% [raw]
# Longterm HospCt only positive if intervnetion is school closure and HospCt is removed- same result with or w/o age 65 plus
