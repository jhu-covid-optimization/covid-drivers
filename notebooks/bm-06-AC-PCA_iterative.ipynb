# %% [raw]
# Beatriz Medeiros
# Notebook for AC-PCA on independent and dependent variables separately

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.linear_model as lm
from collections import defaultdict
import sys; sys.path.append('../')
from src.data_analysis.tools import ac_pca

# %% [markdown]
# ## Get Preprocessed data

# %%
combined_data = pd.read_csv('../data/intermediates/pre_acpca1.csv')
combined_data.set_index('FIPS', inplace=True)
print(combined_data.shape)
ind_vars = list(combined_data.columns)
total_vars = len(ind_vars)
combined_data.head()
# Out:
# (489, 25)
#       inter_movement  out_movement  baseline m50 mobility  \
# FIPS
# 1003        0.519349      0.244188               0.610171
# 1051        0.452205      0.745075               0.840246
# 1055        0.677227      0.378689               0.449395
# 1073        0.775948      0.190299               0.483877
# 1081        0.572121      0.464994               0.307942
#
#       Density per square mile of land area - Population  \
# FIPS
# 1003                                           0.001558
# 1051                                           0.001753
# 1055                                           0.002718
# 1073                                           0.008438
# 1081                                           0.003231
#
#       Rural-urban_Continuum Code_2013  \
# FIPS
# 1003                              0.4
# 1051                              0.2
# 1055                              0.4
# 1073                              0.0
# 1081                              0.4
#
#       Percent of adults with less than a high school diploma 2014-18  \
# FIPS
# 1003                                           0.229851
# 1051                                           0.346269
# 1055                                           0.402985
# 1073                                           0.247761
# 1081                                           0.223881
#
#       Percent of adults with a bachelor's degree or higher 2014-18  \
# FIPS
# 1003                                           0.312698
# 1051                                           0.204762
# 1055                                           0.096825
# 1073                                           0.330159
# 1081                                           0.357143
#
#       Unemployment_rate_2018  Med_HH_Income_Percent_of_State_Total_2018  \
# FIPS
# 1003                0.104938                                   0.373373
# 1051                0.092593                                   0.405917
# 1055                0.135802                                   0.222485
# 1073                0.111111                                   0.342604
# 1081                0.104938                                   0.270414
#
#       Mar Temp AVG / F  ...  \
# FIPS                    ...
# 1003          0.743689  ...
# 1051          0.666019  ...
# 1055          0.598058  ...
# 1073          0.617476  ...
# 1081          0.656311  ...
#
#       SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool  \
# FIPS
# 1003                                           0.417568
# 1051                                           0.378824
# 1055                                           0.294336
# 1073                                           0.520694
# 1081                                           0.586319
#
#       SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten  \
# FIPS
# 1003                                           0.129585
# 1051                                           0.130406
# 1055                                           0.358494
# 1073                                           0.386817
# 1081                                           0.144048
#
#       SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)  \
# FIPS
# 1003                                           0.627997
# 1051                                           0.487643
# 1055                                           0.567540
# 1073                                           0.576102
# 1081                                           0.571650
#
#       SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)  \
# FIPS
# 1003                                           0.462848
# 1051                                           0.645915
# 1055                                           0.360599
# 1073                                           0.416900
# 1081                                           0.442769
#
#       SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school  \
# FIPS
# 1003                                           0.038455
# 1051                                           0.113909
# 1055                                           0.075155
# 1073                                           0.172229
# 1081                                           0.609583
#
#         HospCt  Hispanic Population  Black Population    Deaths  \
# FIPS
# 1003  0.170836             0.038549          0.116681  0.000789
# 1051  0.338853             0.021248          0.290098  0.000789
# 1055  0.261462             0.031866          0.210358  0.000986
# 1073  0.169115             0.031499          0.594907  0.005521
# 1081  0.050141             0.029159          0.312716  0.003943
#
#       normalized_deaths
# FIPS
# 1003           0.010689
# 1051           0.032762
# 1055           0.028791
# 1073           0.013511
# 1081           0.046459
#
# [5 rows x 25 columns]

# %%
ind_vars
# Out:
# ['inter_movement',
#  'out_movement',
#  'baseline m50 mobility',
#  'Density per square mile of land area - Population',
#  'Rural-urban_Continuum Code_2013',
#  'Percent of adults with less than a high school diploma 2014-18',
#  "Percent of adults with a bachelor's degree or higher 2014-18",
#  'Unemployment_rate_2018',
#  'Med_HH_Income_Percent_of_State_Total_2018',
#  'Mar Temp AVG / F',
#  'Apr Temp AVG / F',
#  'May Temp AVG / F',
#  'Jun Temp AVG / F',
#  'Total_age65plus',
#  'Total households!!Average household size',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school',
#  'HospCt',
#  'Hispanic Population',
#  'Black Population',
#  'Deaths',
#  'normalized_deaths']

# %% [markdown]
# ## Run AC-PCA

# %%
def run_acpca(combined_data, confounders):
    ind_vars = list(combined_data.drop(columns=confounders).columns)
    X = combined_data.drop(columns=['Deaths', 'normalized_deaths'], inplace=False)
    X = X.drop(columns=confounders, inplace=False).to_numpy() # 'Density per square mile of land area - Population',
#     print(X.shape)
    X_rows, X_cols = X.shape
    column_names = ['PC' + str(i) for i in range(1, X_cols + 1)]
    if len(confounders) > 0: 
        Y = combined_data.filter(confounders).to_numpy()
    else: 
        Y = np.zeros((X_rows))
    if len(Y.shape) < 2: 
        Y = Y.reshape(len(Y), 1)
    acpca_data, PCs, eigens = ac_pca(X, Y)
    acpca_data = acpca_data.to_numpy()
    PCs = PCs.to_numpy()
    eigens = eigens.to_numpy()
    return acpca_data, PCs, eigens, column_names, ind_vars

# %% [markdown]
# ## Run linear regression on all PCs and get coefficients

# %%
def linreg_coeffs(combined_data, acpca_data, eigens):   
    _, total_pcs = eigens.shape
    pos_pcs = []
    for pc in range(total_pcs): 
        eig = eigens[0,pc]
        if eig > 0: 
            pos_pcs.append(pc)
    if len(pos_pcs) == 0: 
        return 0, 0, pos_pcs
    X = acpca_data[:,pos_pcs]
    Y = combined_data['normalized_deaths']
    reg = lm.LinearRegression().fit(X,Y)
    final_score = reg.score(X,Y)
    coeffs = {}
    for i in range(len(pos_pcs)): 
        coeffs[pos_pcs[i]] = reg.coef_[i]
    return final_score, coeffs, pos_pcs

# %% [markdown]
# ## Calculate individual weight of each variable

# %%
def calc_weights(coeffs, pos_pcs, ind_vars):
    weights = {}
    r,c = PCs.shape
    for pc in pos_pcs: 
        eig = eigens[0, pc]
        PC_dict = {}
        # PC9 = [-0.190896056547888, 0.468236937317933,-0.228567222005448,0.408002822993487,0.0535105125245226,0.407238079363182,0.181820228133276,0.366604933989350,0.435246581102968]
        for i in range(r): 
        #     print('{0:<80} \t {1:>0.3f}'.format(combined_data.columns.values[i+2], PC9[i]))
            loading = PCs[i,pc] # weight of variable in component
            variable = ind_vars[i] # variable name in column headers 
            PC_dict[variable] = loading
            coef = coeffs[pc] # coefficient corresponding to PC
            if variable not in weights:
                weights[variable] = 0
            weights[variable] += coef * loading
    return weights

# %% [markdown]
# ## Print results and identify strongest variable

# %%
def results(weights, final_score, mobility_features):
    print('score:', final_score)
    max_weight = np.max(np.abs(np.array(list(weights.values()))))
    max_var = None
    max_mobility_weight = 0
    max_mobility_var = None
    for var, weight in weights.items():
        if var in mobility_features and weight > max_mobility_weight:
            max_mobility_weight = weight
            max_mobility_var = var
    #     print('{0:<100} & {1:>0.4f} \\\\ \hline'.format(var.replace('_', '\\_'), weight))
        if abs(weight) == max_weight: 
            max_var = var
            print('*** {0:<100} {1:>0.4f}'.format(var, weight))
        else:
            print('{0:<100} {1:>0.4f}'.format(var, weight))
    print('\n\nmax var: ', max_var)
    return max_var, max_weight, max_mobility_var, max_mobility_weight

# %%
mobility_features = ['inter_movement', 'out_movement', 'baseline m50 mobility']
confounders = {} 
it = 0 
while len(confounders) < total_vars - 1:
    print('Iteration', it)
    print('confounders:', *confounders.keys())
    it += 1
    acpca_data, PCs, eigens, column_names, ind_vars = run_acpca(combined_data, confounders)
    final_score, coeffs, pos_pcs = linreg_coeffs(combined_data, acpca_data, eigens)
    if len(pos_pcs) == 0: 
        print('\n\n\n')
        break 
    weights = calc_weights(coeffs, pos_pcs, ind_vars)
    max_var, max_weight, max_mobility_var, max_mobility_weight = results(weights, final_score, mobility_features)
    confounders[max_var] = max_weight
    print('\n\n\n')
for var, weight in confounders.items():
    print('{0:<100} & {1:>0.4f} \\\\hline'.format(var, weight))
# Out:
# Iteration 0
# confounders:
# score: 0.6344357748050589
# inter_movement                                                                                       0.0411
# out_movement                                                                                         0.0921
# baseline m50 mobility                                                                                0.0178
# *** Density per square mile of land area - Population                                                    0.9435
# Rural-urban_Continuum Code_2013                                                                      0.0311
# Percent of adults with less than a high school diploma 2014-18                                       0.0444
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0369
# Unemployment_rate_2018                                                                               0.0520
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0398
# Mar Temp AVG / F                                                                                     -0.0137
# Apr Temp AVG / F                                                                                     -0.1681
# May Temp AVG / F                                                                                     -0.0027
# Jun Temp AVG / F                                                                                     0.1122
# Total_age65plus                                                                                      0.1853
# Total households!!Average household size                                                             0.0712
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0364
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0052
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    0.0245
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0070
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0222
# HospCt                                                                                               0.0278
# Hispanic Population                                                                                  -0.0213
# Black Population                                                                                     0.0279
#
#
# max var:  Density per square mile of land area - Population
#
#
#
#
# Iteration 1
# confounders: Density per square mile of land area - Population
# score: 0.12139788019649933
# inter_movement                                                                                       0.0423
# out_movement                                                                                         0.0960
# baseline m50 mobility                                                                                0.0052
# Rural-urban_Continuum Code_2013                                                                      0.0215
# Percent of adults with less than a high school diploma 2014-18                                       0.0530
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0532
# Unemployment_rate_2018                                                                               0.0508
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0360
# Mar Temp AVG / F                                                                                     -0.0139
# Apr Temp AVG / F                                                                                     -0.1728
# May Temp AVG / F                                                                                     -0.0046
# Jun Temp AVG / F                                                                                     0.1163
# *** Total_age65plus                                                                                      0.1752
# Total households!!Average household size                                                             0.0670
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0369
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0106
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    0.0120
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         -0.0039
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0169
# HospCt                                                                                               0.0261
# Hispanic Population                                                                                  -0.0161
# Black Population                                                                                     0.0335
#
#
# max var:  Total_age65plus
#
#
#
#
# Iteration 2
# confounders: Density per square mile of land area - Population Total_age65plus
# score: 0.10252971384502607
# inter_movement                                                                                       0.0282
# out_movement                                                                                         0.0786
# baseline m50 mobility                                                                                0.0082
# Rural-urban_Continuum Code_2013                                                                      0.0329
# Percent of adults with less than a high school diploma 2014-18                                       0.0214
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0399
# Unemployment_rate_2018                                                                               0.0666
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0539
# Mar Temp AVG / F                                                                                     0.0023
# *** Apr Temp AVG / F                                                                                     -0.1554
# May Temp AVG / F                                                                                     -0.0089
# Jun Temp AVG / F                                                                                     0.1148
# Total households!!Average household size                                                             0.0674
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0294
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0225
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0434
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0071
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0257
# HospCt                                                                                               0.0295
# Hispanic Population                                                                                  -0.0322
# Black Population                                                                                     0.0105
#
#
# max var:  Apr Temp AVG / F
#
#
#
#
# Iteration 3
# confounders: Density per square mile of land area - Population Total_age65plus Apr Temp AVG / F
# score: 0.07796656761784237
# inter_movement                                                                                       0.0274
# out_movement                                                                                         0.0760
# baseline m50 mobility                                                                                0.0061
# Rural-urban_Continuum Code_2013                                                                      0.0340
# Percent of adults with less than a high school diploma 2014-18                                       0.0224
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0338
# Unemployment_rate_2018                                                                               0.0668
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0446
# Mar Temp AVG / F                                                                                     -0.0552
# May Temp AVG / F                                                                                     -0.0292
# *** Jun Temp AVG / F                                                                                     0.0777
# Total households!!Average household size                                                             0.0609
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0313
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0218
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0380
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0093
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0202
# HospCt                                                                                               0.0347
# Hispanic Population                                                                                  -0.0328
# Black Population                                                                                     0.0164
#
#
# max var:  Jun Temp AVG / F
#
#
#
#
# Iteration 4
# confounders: Density per square mile of land area - Population Total_age65plus Apr Temp AVG / F Jun Temp AVG / F
# score: 0.06785880626516638
# inter_movement                                                                                       0.0329
# *** out_movement                                                                                         0.0842
# baseline m50 mobility                                                                                0.0092
# Rural-urban_Continuum Code_2013                                                                      0.0326
# Percent of adults with less than a high school diploma 2014-18                                       0.0377
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0479
# Unemployment_rate_2018                                                                               0.0555
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0594
# Mar Temp AVG / F                                                                                     0.0179
# May Temp AVG / F                                                                                     -0.0339
# Total households!!Average household size                                                             0.0693
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0327
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0199
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0383
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0041
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0233
# HospCt                                                                                               0.0250
# Hispanic Population                                                                                  -0.0497
# Black Population                                                                                     0.0228
#
#
# max var:  out_movement
#
#
#
#
# Iteration 5
# confounders: Density per square mile of land area - Population Total_age65plus Apr Temp AVG / F Jun Temp AVG / F out_movement
# score: 0.04731223547994112
# inter_movement                                                                                       -0.0030
# baseline m50 mobility                                                                                0.0251
# Rural-urban_Continuum Code_2013                                                                      0.0244
# Percent of adults with less than a high school diploma 2014-18                                       0.0559
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0486
# Unemployment_rate_2018                                                                               0.0480
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0423
# Mar Temp AVG / F                                                                                     0.0046
# May Temp AVG / F                                                                                     -0.0256
# *** Total households!!Average household size                                                             0.0661
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0353
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0188
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0408
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0076
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0178
# HospCt                                                                                               0.0303
# Hispanic Population                                                                                  -0.0505
# Black Population                                                                                     0.0287
#
#
# max var:  Total households!!Average household size
#
#
#
#
# Iteration 6
# confounders: Density per square mile of land area - Population Total_age65plus Apr Temp AVG / F Jun Temp AVG / F out_movement Total households!!Average household size
# score: 0.05019340603754008
# inter_movement                                                                                       -0.0095
# baseline m50 mobility                                                                                0.0295
# Rural-urban_Continuum Code_2013                                                                      0.0211
# *** Percent of adults with less than a high school diploma 2014-18                                       0.0746
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0494
# Unemployment_rate_2018                                                                               0.0449
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0432
# Mar Temp AVG / F                                                                                     0.0212
# May Temp AVG / F                                                                                     -0.0393
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0396
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0177
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0150
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0138
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0161
# HospCt                                                                                               0.0255
# Hispanic Population                                                                                  -0.0442
# Black Population                                                                                     0.0275
#
#
# max var:  Percent of adults with less than a high school diploma 2014-18
#
#
#
#
# Iteration 7
# confounders: Density per square mile of land area - Population Total_age65plus Apr Temp AVG / F Jun Temp AVG / F out_movement Total households!!Average household size Percent of adults with less than a high school diploma 2014-18
# score: 0.030428345775563637
# inter_movement                                                                                       -0.0018
# baseline m50 mobility                                                                                0.0177
# Rural-urban_Continuum Code_2013                                                                      0.0196
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0501
# *** Unemployment_rate_2018                                                                               0.0638
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0312
# Mar Temp AVG / F                                                                                     0.0265
# May Temp AVG / F                                                                                     -0.0288
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0371
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0208
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0077
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0248
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0210
# HospCt                                                                                               0.0234
# Hispanic Population                                                                                  -0.0177
# Black Population                                                                                     0.0239
#
#
# max var:  Unemployment_rate_2018
#
#
#
#
# Iteration 8
# confounders: Density per square mile of land area - Population Total_age65plus Apr Temp AVG / F Jun Temp AVG / F out_movement Total households!!Average household size Percent of adults with less than a high school diploma 2014-18 Unemployment_rate_2018
# score: 0.02027772856867216
# inter_movement                                                                                       0.0108
# baseline m50 mobility                                                                                0.0315
# Rural-urban_Continuum Code_2013                                                                      0.0260
# *** Percent of adults with a bachelor's degree or higher 2014-18                                         0.0458
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0316
# Mar Temp AVG / F                                                                                     0.0135
# May Temp AVG / F                                                                                     -0.0211
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0330
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0188
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0059
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0135
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0324
# HospCt                                                                                               0.0264
# Hispanic Population                                                                                  0.0078
# Black Population                                                                                     0.0163
#
#
# max var:  Percent of adults with a bachelor's degree or higher 2014-18
#
#
#
#
# Iteration 9
# confounders: Density per square mile of land area - Population Total_age65plus Apr Temp AVG / F Jun Temp AVG / F out_movement Total households!!Average household size Percent of adults with less than a high school diploma 2014-18 Unemployment_rate_2018 Percent of adults with a bachelor's degree or higher 2014-18
# score: 0.018128860351200204
# inter_movement                                                                                       0.0163
# baseline m50 mobility                                                                                0.0100
# Rural-urban_Continuum Code_2013                                                                      0.0007
# Med_HH_Income_Percent_of_State_Total_2018                                                            0.0110
# Mar Temp AVG / F                                                                                     0.0110
# May Temp AVG / F                                                                                     -0.0259
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0258
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0248
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0030
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         -0.0012
# *** SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0357
# HospCt                                                                                               0.0221
# Hispanic Population                                                                                  0.0036
# Black Population                                                                                     0.0278
#
#
# max var:  SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school
#
#
#
#
# Iteration 10
# confounders: Density per square mile of land area - Population Total_age65plus Apr Temp AVG / F Jun Temp AVG / F out_movement Total households!!Average household size Percent of adults with less than a high school diploma 2014-18 Unemployment_rate_2018 Percent of adults with a bachelor's degree or higher 2014-18 SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school
# score: 0.00867636486562784
# inter_movement                                                                                       0.0136
# *** baseline m50 mobility                                                                                0.0284
# Rural-urban_Continuum Code_2013                                                                      0.0117
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0019
# Mar Temp AVG / F                                                                                     0.0100
# May Temp AVG / F                                                                                     -0.0217
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0271
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0208
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0238
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0102
# HospCt                                                                                               0.0067
# Hispanic Population                                                                                  0.0114
# Black Population                                                                                     0.0158
#
#
# max var:  baseline m50 mobility
#
#
#
#
# Iteration 11
# confounders: Density per square mile of land area - Population Total_age65plus Apr Temp AVG / F Jun Temp AVG / F out_movement Total households!!Average household size Percent of adults with less than a high school diploma 2014-18 Unemployment_rate_2018 Percent of adults with a bachelor's degree or higher 2014-18 SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school baseline m50 mobility
# score: 0.00413219324148939
# inter_movement                                                                                       0.0054
# Rural-urban_Continuum Code_2013                                                                      -0.0114
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0030
# Mar Temp AVG / F                                                                                     0.0066
# May Temp AVG / F                                                                                     -0.0124
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          -0.0104
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0012
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0201
# *** SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0212
# HospCt                                                                                               0.0146
# Hispanic Population                                                                                  0.0004
# Black Population                                                                                     0.0146
#
#
# max var:  SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)
#
#
#
#
# Iteration 12
# confounders: Density per square mile of land area - Population Total_age65plus Apr Temp AVG / F Jun Temp AVG / F out_movement Total households!!Average household size Percent of adults with less than a high school diploma 2014-18 Unemployment_rate_2018 Percent of adults with a bachelor's degree or higher 2014-18 SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school baseline m50 mobility SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)
# score: 0.00013196496242573463
# inter_movement                                                                                       -0.0001
# Rural-urban_Continuum Code_2013                                                                      -0.0025
# *** Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0039
# Mar Temp AVG / F                                                                                     -0.0015
# May Temp AVG / F                                                                                     0.0021
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0023
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0029
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    0.0008
# HospCt                                                                                               -0.0009
# Hispanic Population                                                                                  -0.0003
# Black Population                                                                                     -0.0019
#
#
# max var:  Med_HH_Income_Percent_of_State_Total_2018
#
#
#
#
# Iteration 13
# confounders: Density per square mile of land area - Population Total_age65plus Apr Temp AVG / F Jun Temp AVG / F out_movement Total households!!Average household size Percent of adults with less than a high school diploma 2014-18 Unemployment_rate_2018 Percent of adults with a bachelor's degree or higher 2014-18 SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school baseline m50 mobility SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12) Med_HH_Income_Percent_of_State_Total_2018
# score: 0.0003735279596268626
# inter_movement                                                                                       0.0005
# Rural-urban_Continuum Code_2013                                                                      0.0007
# Mar Temp AVG / F                                                                                     -0.0038
# May Temp AVG / F                                                                                     0.0031
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          -0.0026
# *** SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0074
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    0.0032
# HospCt                                                                                               -0.0055
# Hispanic Population                                                                                  0.0014
# Black Population                                                                                     0.0011
#
#
# max var:  SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten
#
#
#
#
# Iteration 14
# confounders: Density per square mile of land area - Population Total_age65plus Apr Temp AVG / F Jun Temp AVG / F out_movement Total households!!Average household size Percent of adults with less than a high school diploma 2014-18 Unemployment_rate_2018 Percent of adults with a bachelor's degree or higher 2014-18 SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school baseline m50 mobility SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12) Med_HH_Income_Percent_of_State_Total_2018 SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten
#
#
#
#
# Density per square mile of land area - Population                                                    0.9435
# Total_age65plus                                                                                      0.1752
# Apr Temp AVG / F                                                                                     0.1554
# Jun Temp AVG / F                                                                                     0.0777
# out_movement                                                                                         0.0842
# Total households!!Average household size                                                             0.0661
# Percent of adults with less than a high school diploma 2014-18                                       0.0746
# Unemployment_rate_2018                                                                               0.0638
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0458
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0357
# baseline m50 mobility                                                                                0.0284
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0212
# Med_HH_Income_Percent_of_State_Total_2018                                                            0.0039
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      0.0074
