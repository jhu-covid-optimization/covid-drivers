# %% [raw]
# Beatriz Medeiros
# Notebook for AC-PCA on independent and dependent variables separately

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.linear_model as lm
from collections import defaultdict
import sys; sys.path.append('../')
from src.data_analysis.tools import ac_pca

# %% [markdown]
# ## Get Preprocessed data

# %%
combined_data = pd.read_csv('../data/intermediates/pre_acpca1.csv')
combined_data.set_index('FIPS', inplace=True)
print(combined_data.shape)
ind_vars = list(combined_data.columns)
total_vars = len(ind_vars)
combined_data.head()
# Out:
# (444, 27)
#       Unnamed: 0  2wk Prior Mobility  2wk Onset Mobility  2wk Post Mobility  \
# FIPS
# 1003           0            0.459962            0.738688           0.824197
# 1051           1            0.521206            0.785409           0.844992
# 1073           2            0.581889            0.834773           0.879697
# 1081           3            0.301939            0.575735           0.703762
# 1089           4            0.492726            0.741843           0.824973
#
#       inter_movement  out_movement  baseline m50 mobility  \
# FIPS
# 1003        0.519349      0.327736               0.663421
# 1051        0.452205      1.000000               0.913574
# 1073        0.775948      0.255409               0.526105
# 1081        0.572121      0.624091               0.334816
# 1089        0.686220      0.197095               0.553652
#
#       Density per square mile of land area - Population  \
# FIPS
# 1003                                           0.001558
# 1051                                           0.001753
# 1073                                           0.008438
# 1081                                           0.003231
# 1089                                           0.005921
#
#       Rural-urban_Continuum Code_2013  \
# FIPS
# 1003                              0.4
# 1051                              0.2
# 1073                              0.0
# 1081                              0.4
# 1089                              0.2
#
#       Percent of adults with less than a high school diploma 2014-18  ...  \
# FIPS                                                                  ...
# 1003                                           0.229851               ...
# 1051                                           0.346269               ...
# 1073                                           0.247761               ...
# 1081                                           0.223881               ...
# 1089                                           0.205970               ...
#
#       SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)  \
# FIPS
# 1003                                           0.627997
# 1051                                           0.487643
# 1073                                           0.576102
# 1081                                           0.571650
# 1089                                           0.502458
#
#       SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)  \
# FIPS
# 1003                                           0.500158
# 1051                                           0.710296
# 1073                                           0.447416
# 1081                                           0.477111
# 1089                                           0.524013
#
#       SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school  \
# FIPS
# 1003                                           0.023750
# 1051                                           0.104400
# 1073                                           0.166735
# 1081                                           0.634204
# 1089                                           0.251270
#
#         HospCt  Hispanic Population  Black Population  \
# FIPS
# 1003  0.170836             0.038549          0.116048
# 1051  0.338853             0.021248          0.289589
# 1073  0.169115             0.031499          0.594616
# 1081  0.050141             0.029159          0.312223
# 1089  0.082998             0.043017          0.337374
#
#       Outbreak Month Temp AVG / F  Time from outbreak to intervention  \
# FIPS
# 1003                     0.754826                            0.959795
# 1051                     0.928571                            0.947819
# 1073                     0.698842                            0.976048
# 1081                     0.708494                            0.974337
# 1089                     0.666023                            0.969204
#
#         Deaths  normalized_deaths
# FIPS
# 1003  0.000591           0.006585
# 1051  0.000788           0.025222
# 1073  0.005518           0.012855
# 1081  0.003745           0.040884
# 1089  0.000197           0.001246
#
# [5 rows x 27 columns]

# %%
ind_vars
# Out:
# ['Unnamed: 0',
#  '2wk Prior Mobility',
#  '2wk Onset Mobility',
#  '2wk Post Mobility',
#  'inter_movement',
#  'out_movement',
#  'baseline m50 mobility',
#  'Density per square mile of land area - Population',
#  'Rural-urban_Continuum Code_2013',
#  'Percent of adults with less than a high school diploma 2014-18',
#  "Percent of adults with a bachelor's degree or higher 2014-18",
#  'Unemployment_rate_2018',
#  'Med_HH_Income_Percent_of_State_Total_2018',
#  'Total_age65plus',
#  'Total households!!Average household size',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school',
#  'HospCt',
#  'Hispanic Population',
#  'Black Population',
#  'Outbreak Month Temp AVG / F',
#  'Time from outbreak to intervention',
#  'Deaths',
#  'normalized_deaths']

# %% [markdown]
# ## Run AC-PCA

# %%
def run_acpca(combined_data, confounders):
    ind_vars = list(combined_data.drop(columns=confounders).columns)
    X = combined_data.drop(columns=['Deaths', 'normalized_deaths'], inplace=False)
    X = X.drop(columns=confounders, inplace=False).to_numpy() # 'Density per square mile of land area - Population',
#     print(X.shape)
    X_rows, X_cols = X.shape
    column_names = ['PC' + str(i) for i in range(1, X_cols + 1)]
    if len(confounders) > 0: 
        Y = combined_data.filter(confounders).to_numpy()
    else: 
        Y = np.zeros((X_rows))
    if len(Y.shape) < 2: 
        Y = Y.reshape(len(Y), 1)
    acpca_data, PCs, eigens = ac_pca(X, Y)
    acpca_data = acpca_data.to_numpy()
    PCs = PCs.to_numpy()
    eigens = eigens.to_numpy()
    return acpca_data, PCs, eigens, column_names, ind_vars

# %% [markdown]
# ## Run linear regression on all PCs and get coefficients

# %%
def linreg_coeffs(combined_data, acpca_data, eigens):   
    _, total_pcs = eigens.shape
    pos_pcs = []
    for pc in range(total_pcs): 
        eig = eigens[0,pc]
        if eig > 0: 
            pos_pcs.append(pc)
    if len(pos_pcs) == 0: 
        return 0, 0, pos_pcs
    X = acpca_data[:,pos_pcs]
    Y = combined_data['normalized_deaths']
    reg = lm.LinearRegression().fit(X,Y)
    final_score = reg.score(X,Y)
    coeffs = {}
    for i in range(len(pos_pcs)): 
        coeffs[pos_pcs[i]] = reg.coef_[i]
    return final_score, coeffs, pos_pcs

# %% [markdown]
# ## Calculate individual weight of each variable

# %%
def calc_weights(coeffs, pos_pcs, ind_vars):
    weights = {}
    r,c = PCs.shape
    for pc in pos_pcs: 
        eig = eigens[0, pc]
        PC_dict = {}
        # PC9 = [-0.190896056547888, 0.468236937317933,-0.228567222005448,0.408002822993487,0.0535105125245226,0.407238079363182,0.181820228133276,0.366604933989350,0.435246581102968]
        for i in range(r): 
        #     print('{0:<80} \t {1:>0.3f}'.format(combined_data.columns.values[i+2], PC9[i]))
            loading = PCs[i,pc] # weight of variable in component
            variable = ind_vars[i] # variable name in column headers 
            PC_dict[variable] = loading
            coef = coeffs[pc] # coefficient corresponding to PC
            if variable not in weights:
                weights[variable] = 0
            weights[variable] += coef * loading
    return weights

# %% [markdown]
# ## Print results and identify strongest variable

# %%
def results(weights, final_score, mobility_features):
    print('score:', final_score)
    max_weight_mag = np.max(np.abs(np.array(list(weights.values()))))
    max_weight = 0
    max_var = None
    max_mobility_weight = 0
    max_mobility_var = None
    for var, weight in weights.items():
        if var in mobility_features and weight > max_mobility_weight:
            max_mobility_weight = weight
            max_mobility_var = var
    #     print('{0:<100} & {1:>0.4f} \\\\ \hline'.format(var.replace('_', '\\_'), weight))
        if abs(weight) == max_weight_mag: 
            max_weight = weight
            max_var = var
            print('*** {0:<100} {1:>0.4f}'.format(var, weight))
        else:
            print('{0:<100} {1:>0.4f}'.format(var, weight))
    print('\n\nmax var: ', max_var)
    return max_var, max_weight, max_mobility_var, max_mobility_weight

# %%
mobility_features = ['inter_movement', 'out_movement', 'baseline m50 mobility']
confounders = {} 
it = 0 
while len(confounders) < total_vars - 1:
    print('Iteration', it)
    print('confounders:', *confounders.keys())
    it += 1
    acpca_data, PCs, eigens, column_names, ind_vars = run_acpca(combined_data, confounders)
    final_score, coeffs, pos_pcs = linreg_coeffs(combined_data, acpca_data, eigens)
    if len(pos_pcs) == 0: 
        print('\n\n\n')
        break 
    weights = calc_weights(coeffs, pos_pcs, ind_vars)
    max_var, max_weight, max_mobility_var, max_mobility_weight = results(weights, final_score, mobility_features)
    confounders[max_var] = max_weight
    print('\n\n\n')
for var, weight in confounders.items():
    print('{0:<100} & {1:>0.4f} \\\\hline'.format(var, weight))
# Out:
# Iteration 0
# confounders:
# score: 0.7079535905201758
# Unnamed: 0                                                                                           0.0000
# 2wk Prior Mobility                                                                                   0.0187
# 2wk Onset Mobility                                                                                   0.0200
# 2wk Post Mobility                                                                                    -0.0282
# inter_movement                                                                                       0.0217
# out_movement                                                                                         0.0653
# baseline m50 mobility                                                                                0.0390
# *** Density per square mile of land area - Population                                                    0.9546
# Rural-urban_Continuum Code_2013                                                                      0.0530
# Percent of adults with less than a high school diploma 2014-18                                       0.0031
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0176
# Unemployment_rate_2018                                                                               0.0388
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0421
# Total_age65plus                                                                                      0.2189
# Total households!!Average household size                                                             0.0387
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0434
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      0.0076
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    0.0533
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0377
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0559
# HospCt                                                                                               0.0260
# Hispanic Population                                                                                  -0.0084
# Black Population                                                                                     0.0345
# Outbreak Month Temp AVG / F                                                                          -0.0781
# Time from outbreak to intervention                                                                   -0.0156
#
#
# max var:  Density per square mile of land area - Population
#
#
#
#
# Iteration 1
# confounders: Density per square mile of land area - Population
# score: 0.13565827552533438
# Unnamed: 0                                                                                           0.0000
# 2wk Prior Mobility                                                                                   0.0310
# 2wk Onset Mobility                                                                                   0.0267
# 2wk Post Mobility                                                                                    -0.0369
# inter_movement                                                                                       0.0141
# out_movement                                                                                         0.0731
# baseline m50 mobility                                                                                0.0206
# Rural-urban_Continuum Code_2013                                                                      0.0424
# Percent of adults with less than a high school diploma 2014-18                                       0.0229
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0417
# Unemployment_rate_2018                                                                               0.0387
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0367
# *** Total_age65plus                                                                                      0.1988
# Total households!!Average household size                                                             0.0329
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0437
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0005
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    0.0337
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0233
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0472
# HospCt                                                                                               0.0277
# Hispanic Population                                                                                  -0.0045
# Black Population                                                                                     0.0392
# Outbreak Month Temp AVG / F                                                                          -0.0847
# Time from outbreak to intervention                                                                   -0.0140
#
#
# max var:  Total_age65plus
#
#
#
#
# Iteration 2
# confounders: Density per square mile of land area - Population Total_age65plus
# score: 0.10826650337449839
# Unnamed: 0                                                                                           0.0000
# 2wk Prior Mobility                                                                                   0.0341
# 2wk Onset Mobility                                                                                   -0.0259
# 2wk Post Mobility                                                                                    0.0059
# inter_movement                                                                                       0.0115
# out_movement                                                                                         0.0559
# baseline m50 mobility                                                                                0.0284
# Rural-urban_Continuum Code_2013                                                                      0.0592
# Percent of adults with less than a high school diploma 2014-18                                       -0.0136
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0202
# Unemployment_rate_2018                                                                               0.0566
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0453
# Total households!!Average household size                                                             0.0390
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0313
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0156
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0467
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0240
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0131
# HospCt                                                                                               0.0305
# Hispanic Population                                                                                  -0.0048
# Black Population                                                                                     0.0222
# *** Outbreak Month Temp AVG / F                                                                          -0.0660
# Time from outbreak to intervention                                                                   -0.0119
#
#
# max var:  Outbreak Month Temp AVG / F
#
#
#
#
# Iteration 3
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F
# score: 0.07107824467626689
# Unnamed: 0                                                                                           0.0000
# 2wk Prior Mobility                                                                                   0.0823
# *** 2wk Onset Mobility                                                                                   -0.0920
# 2wk Post Mobility                                                                                    0.0627
# inter_movement                                                                                       -0.0071
# out_movement                                                                                         0.0658
# baseline m50 mobility                                                                                0.0059
# Rural-urban_Continuum Code_2013                                                                      0.0455
# Percent of adults with less than a high school diploma 2014-18                                       -0.0039
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0453
# Unemployment_rate_2018                                                                               0.0621
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0628
# Total households!!Average household size                                                             0.0154
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0356
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0105
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0296
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0333
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0100
# HospCt                                                                                               0.0372
# Hispanic Population                                                                                  -0.0120
# Black Population                                                                                     0.0118
# Time from outbreak to intervention                                                                   -0.0067
#
#
# max var:  2wk Onset Mobility
#
#
#
#
# Iteration 4
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility
# score: 0.0677454389674631
# Unnamed: 0                                                                                           0.0000
# 2wk Prior Mobility                                                                                   0.0477
# 2wk Post Mobility                                                                                    -0.0055
# inter_movement                                                                                       -0.0054
# out_movement                                                                                         0.0642
# baseline m50 mobility                                                                                0.0022
# Rural-urban_Continuum Code_2013                                                                      0.0395
# Percent of adults with less than a high school diploma 2014-18                                       -0.0034
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0528
# Unemployment_rate_2018                                                                               0.0609
# *** Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0752
# Total households!!Average household size                                                             0.0171
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0366
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0081
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0295
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0371
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0132
# HospCt                                                                                               0.0375
# Hispanic Population                                                                                  -0.0218
# Black Population                                                                                     0.0054
# Time from outbreak to intervention                                                                   -0.0039
#
#
# max var:  Med_HH_Income_Percent_of_State_Total_2018
#
#
#
#
# Iteration 5
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility Med_HH_Income_Percent_of_State_Total_2018
# score: 0.058720646566243984
# Unnamed: 0                                                                                           0.0000
# 2wk Prior Mobility                                                                                   0.0462
# 2wk Post Mobility                                                                                    0.0018
# inter_movement                                                                                       -0.0169
# out_movement                                                                                         0.0553
# baseline m50 mobility                                                                                -0.0152
# Rural-urban_Continuum Code_2013                                                                      0.0362
# Percent of adults with less than a high school diploma 2014-18                                       -0.0011
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0115
# *** Unemployment_rate_2018                                                                               0.0705
# Total households!!Average household size                                                             -0.0106
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0357
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0075
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0310
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0430
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0032
# HospCt                                                                                               0.0352
# Hispanic Population                                                                                  -0.0176
# Black Population                                                                                     0.0061
# Time from outbreak to intervention                                                                   -0.0031
#
#
# max var:  Unemployment_rate_2018
#
#
#
#
# Iteration 6
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility Med_HH_Income_Percent_of_State_Total_2018 Unemployment_rate_2018
# score: 0.048435057617834065
# Unnamed: 0                                                                                           -0.0000
# 2wk Prior Mobility                                                                                   0.0434
# 2wk Post Mobility                                                                                    0.0026
# inter_movement                                                                                       -0.0162
# *** out_movement                                                                                         0.0528
# baseline m50 mobility                                                                                -0.0185
# Rural-urban_Continuum Code_2013                                                                      0.0348
# Percent of adults with less than a high school diploma 2014-18                                       -0.0016
# Percent of adults with a bachelor's degree or higher 2014-18                                         -0.0070
# Total households!!Average household size                                                             -0.0238
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0348
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0065
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0285
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0411
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0123
# HospCt                                                                                               0.0321
# Hispanic Population                                                                                  -0.0101
# Black Population                                                                                     0.0077
# Time from outbreak to intervention                                                                   -0.0052
#
#
# max var:  out_movement
#
#
#
#
# Iteration 7
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility Med_HH_Income_Percent_of_State_Total_2018 Unemployment_rate_2018 out_movement
# score: 0.02893632300469917
# Unnamed: 0                                                                                           0.0000
# 2wk Prior Mobility                                                                                   0.0278
# 2wk Post Mobility                                                                                    -0.0181
# inter_movement                                                                                       -0.0166
# baseline m50 mobility                                                                                -0.0026
# Rural-urban_Continuum Code_2013                                                                      0.0317
# Percent of adults with less than a high school diploma 2014-18                                       0.0007
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0084
# Total households!!Average household size                                                             -0.0048
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0352
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0069
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0302
# *** SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0374
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0015
# HospCt                                                                                               0.0328
# Hispanic Population                                                                                  -0.0143
# Black Population                                                                                     0.0137
# Time from outbreak to intervention                                                                   -0.0036
#
#
# max var:  SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)
#
#
#
#
# Iteration 8
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility Med_HH_Income_Percent_of_State_Total_2018 Unemployment_rate_2018 out_movement SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)
# score: 0.022879182801962546
# Unnamed: 0                                                                                           0.0000
# 2wk Prior Mobility                                                                                   0.0318
# 2wk Post Mobility                                                                                    -0.0188
# inter_movement                                                                                       -0.0195
# baseline m50 mobility                                                                                -0.0039
# Rural-urban_Continuum Code_2013                                                                      0.0232
# Percent of adults with less than a high school diploma 2014-18                                       -0.0027
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0019
# Total households!!Average household size                                                             0.0220
# *** SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0350
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0054
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0065
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0107
# HospCt                                                                                               0.0329
# Hispanic Population                                                                                  -0.0219
# Black Population                                                                                     0.0020
# Time from outbreak to intervention                                                                   -0.0076
#
#
# max var:  SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool
#
#
#
#
# Iteration 9
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility Med_HH_Income_Percent_of_State_Total_2018 Unemployment_rate_2018 out_movement SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12) SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool
# score: 0.019467531094551793
# Unnamed: 0                                                                                           0.0000
# *** 2wk Prior Mobility                                                                                   0.0344
# 2wk Post Mobility                                                                                    -0.0145
# inter_movement                                                                                       -0.0225
# baseline m50 mobility                                                                                -0.0083
# Rural-urban_Continuum Code_2013                                                                      0.0203
# Percent of adults with less than a high school diploma 2014-18                                       0.0005
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0170
# Total households!!Average household size                                                             0.0254
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0060
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    0.0095
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0107
# HospCt                                                                                               0.0316
# Hispanic Population                                                                                  -0.0271
# Black Population                                                                                     0.0069
# Time from outbreak to intervention                                                                   -0.0105
#
#
# max var:  2wk Prior Mobility
#
#
#
#
# Iteration 10
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility Med_HH_Income_Percent_of_State_Total_2018 Unemployment_rate_2018 out_movement SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12) SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool 2wk Prior Mobility
# score: 0.013485605063152661
# Unnamed: 0                                                                                           0.0000
# 2wk Post Mobility                                                                                    -0.0004
# inter_movement                                                                                       -0.0061
# baseline m50 mobility                                                                                -0.0024
# Rural-urban_Continuum Code_2013                                                                      0.0182
# Percent of adults with less than a high school diploma 2014-18                                       0.0108
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0213
# Total households!!Average household size                                                             0.0018
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0059
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    0.0096
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0132
# *** HospCt                                                                                               0.0337
# Hispanic Population                                                                                  -0.0054
# Black Population                                                                                     0.0036
# Time from outbreak to intervention                                                                   -0.0180
#
#
# max var:  HospCt
#
#
#
#
# Iteration 11
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility Med_HH_Income_Percent_of_State_Total_2018 Unemployment_rate_2018 out_movement SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12) SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool 2wk Prior Mobility HospCt
# score: 0.008088101483865628
# Unnamed: 0                                                                                           0.0000
# 2wk Post Mobility                                                                                    0.0022
# inter_movement                                                                                       -0.0043
# baseline m50 mobility                                                                                -0.0015
# Rural-urban_Continuum Code_2013                                                                      0.0073
# Percent of adults with less than a high school diploma 2014-18                                       -0.0003
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0061
# Total households!!Average household size                                                             0.0004
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0083
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0050
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0125
# *** Hispanic Population                                                                                  0.0153
# Black Population                                                                                     0.0070
# Time from outbreak to intervention                                                                   -0.0144
#
#
# max var:  Hispanic Population
#
#
#
#
# Iteration 12
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility Med_HH_Income_Percent_of_State_Total_2018 Unemployment_rate_2018 out_movement SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12) SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool 2wk Prior Mobility HospCt Hispanic Population
# score: 0.008073820908087948
# Unnamed: 0                                                                                           0.0000
# 2wk Post Mobility                                                                                    0.0027
# inter_movement                                                                                       -0.0002
# baseline m50 mobility                                                                                -0.0039
# Rural-urban_Continuum Code_2013                                                                      0.0093
# Percent of adults with less than a high school diploma 2014-18                                       0.0030
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0065
# Total households!!Average household size                                                             0.0138
# *** SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0147
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0057
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0076
# Black Population                                                                                     0.0062
# Time from outbreak to intervention                                                                   0.0030
#
#
# max var:  SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten
#
#
#
#
# Iteration 13
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility Med_HH_Income_Percent_of_State_Total_2018 Unemployment_rate_2018 out_movement SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12) SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool 2wk Prior Mobility HospCt Hispanic Population SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten
# score: 0.004366591959146904
# Unnamed: 0                                                                                           0.0000
# 2wk Post Mobility                                                                                    -0.0008
# inter_movement                                                                                       0.0022
# baseline m50 mobility                                                                                -0.0035
# Rural-urban_Continuum Code_2013                                                                      0.0070
# Percent of adults with less than a high school diploma 2014-18                                       -0.0036
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0019
# *** Total households!!Average household size                                                             0.0156
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0115
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0061
# Black Population                                                                                     0.0055
# Time from outbreak to intervention                                                                   0.0140
#
#
# max var:  Total households!!Average household size
#
#
#
#
# Iteration 14
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility Med_HH_Income_Percent_of_State_Total_2018 Unemployment_rate_2018 out_movement SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12) SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool 2wk Prior Mobility HospCt Hispanic Population SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten Total households!!Average household size
#
#
#
#
# Density per square mile of land area - Population                                                    & 0.9546 \\hline
# Total_age65plus                                                                                      & 0.1988 \\hline
# Outbreak Month Temp AVG / F                                                                          & -0.0660 \\hline
# 2wk Onset Mobility                                                                                   & -0.0920 \\hline
# Med_HH_Income_Percent_of_State_Total_2018                                                            & -0.0752 \\hline
# Unemployment_rate_2018                                                                               & 0.0705 \\hline
# out_movement                                                                                         & 0.0528 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         & 0.0374 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          & 0.0350 \\hline
# 2wk Prior Mobility                                                                                   & 0.0344 \\hline
# HospCt                                                                                               & 0.0337 \\hline
# Hispanic Population                                                                                  & 0.0153 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      & -0.0147 \\hline
# Total households!!Average household size                                                             & 0.0156 \\hline

# %% [raw]
# problems: 2wk mobility averages and time from outbreak to intervention should all be positive

# %% [raw]
# interventon date - outbreak
# neg if intervention happens before outbreak (neg in most cases)
# pos if outbreak before intervention
# 0 if same day
