# %% [raw]
# Beatriz Medeiros
# Notebook for AC-PCA on independent and dependent variables separately

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.linear_model as lm
from collections import defaultdict
import sys; sys.path.append('../')
from src.data_analysis.tools import ac_pca

# %% [markdown]
# ## Get Preprocessed data

# %%
combined_data = pd.read_csv('../data/processed/pre_acpca.csv')
# combined_data = combined_data.drop(columns='Total_age65plus')
# combined_data = combined_data.drop(columns='HospCt')
combined_data.set_index('FIPS', inplace=True)
print(combined_data.shape)
ind_vars = list(combined_data.columns)
total_vars = len(ind_vars)
combined_data.head()
# Out:
# (450, 28)
#       2wk Prior Mobility  2wk Onset Mobility  2wk Post Mobility  \
# FIPS
# 1003            0.459962            0.738688           0.824197
# 1051            0.521206            0.785409           0.844992
# 1073            0.581889            0.834773           0.879697
# 1081            0.301939            0.575735           0.703762
# 1089            0.492726            0.741843           0.824973
#
#       inter_movement  out_movement  baseline m50 mobility  \
# FIPS
# 1003        0.519349      0.327736               0.663421
# 1051        0.452205      1.000000               0.913574
# 1073        0.775948      0.255409               0.526105
# 1081        0.572121      0.624091               0.334816
# 1089        0.686220      0.197095               0.553652
#
#       Density per square mile of land area - Population  \
# FIPS
# 1003                                           0.001558
# 1051                                           0.001753
# 1073                                           0.008438
# 1081                                           0.003231
# 1089                                           0.005921
#
#       Rural-urban_Continuum Code_2013  \
# FIPS
# 1003                              0.4
# 1051                              0.2
# 1073                              0.0
# 1081                              0.4
# 1089                              0.2
#
#       Percent of adults with less than a high school diploma 2014-18  \
# FIPS
# 1003                                           0.229851
# 1051                                           0.346269
# 1073                                           0.247761
# 1081                                           0.223881
# 1089                                           0.205970
#
#       Percent of adults with a bachelor's degree or higher 2014-18  ...  \
# FIPS                                                                ...
# 1003                                           0.312698             ...
# 1051                                           0.204762             ...
# 1073                                           0.330159             ...
# 1081                                           0.357143             ...
# 1089                                           0.477778             ...
#
#       SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school  \
# FIPS
# 1003                                           0.023750
# 1051                                           0.104400
# 1073                                           0.166735
# 1081                                           0.634204
# 1089                                           0.251270
#
#         HospCt  Longterm HospCt  Hispanic Population  Black Population  \
# FIPS
# 1003  0.207274         0.000000             0.038549          0.116048
# 1051  0.367907         0.000000             0.021248          0.289589
# 1073  0.205628         0.114238             0.031499          0.594616
# 1081  0.091883         0.000000             0.029159          0.312223
# 1089  0.123296         0.000000             0.043017          0.337374
#
#       Outbreak Month Temp AVG / F  Time from outbreak to intervention  \
# FIPS
# 1003                     0.754826                              0.4625
# 1051                     0.928571                              0.3125
# 1073                     0.698842                              0.6750
# 1081                     0.708494                              0.6500
# 1089                     0.666023                              0.5750
#
#       Time from outbreak to national intervention    Deaths  normalized_deaths
# FIPS
# 1003                                     0.395062  0.000591           0.006585
# 1051                                     0.222222  0.000788           0.025222
# 1073                                     0.629630  0.005518           0.012855
# 1081                                     0.604938  0.003745           0.040884
# 1089                                     0.530864  0.000197           0.001246
#
# [5 rows x 28 columns]

# %%
ind_vars
# Out:
# ['2wk Prior Mobility',
#  '2wk Onset Mobility',
#  '2wk Post Mobility',
#  'inter_movement',
#  'out_movement',
#  'baseline m50 mobility',
#  'Density per square mile of land area - Population',
#  'Rural-urban_Continuum Code_2013',
#  'Percent of adults with less than a high school diploma 2014-18',
#  "Percent of adults with a bachelor's degree or higher 2014-18",
#  'Unemployment_rate_2018',
#  'Med_HH_Income_Percent_of_State_Total_2018',
#  'Total_age65plus',
#  'Total households!!Average household size',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school',
#  'HospCt',
#  'Longterm HospCt',
#  'Hispanic Population',
#  'Black Population',
#  'Outbreak Month Temp AVG / F',
#  'Time from outbreak to intervention',
#  'Time from outbreak to national intervention',
#  'Deaths',
#  'normalized_deaths']

# %% [markdown]
# ## Run AC-PCA

# %%
def run_acpca(combined_data, confounders):
    ind_vars = list(combined_data.drop(columns=confounders).columns)
    X = combined_data.drop(columns=['Deaths', 'normalized_deaths'], inplace=False)
    X = X.drop(columns=confounders, inplace=False).to_numpy() # 'Density per square mile of land area - Population',
#     print(X.shape)
    X_rows, X_cols = X.shape
    column_names = ['PC' + str(i) for i in range(1, X_cols + 1)]
    if len(confounders) > 0: 
        Y = combined_data.filter(confounders).to_numpy()
    else: 
        Y = np.zeros((X_rows))
    if len(Y.shape) < 2: 
        Y = Y.reshape(len(Y), 1)
    acpca_data, PCs, eigens = ac_pca(X, Y)
    acpca_data = acpca_data.to_numpy()
    PCs = PCs.to_numpy()
    eigens = eigens.to_numpy()
    return acpca_data, PCs, eigens, column_names, ind_vars

# %% [markdown]
# ## Run linear regression on all PCs and get coefficients

# %%
def linreg_coeffs(combined_data, acpca_data, eigens):   
    _, total_pcs = eigens.shape
    pos_pcs = []
    for pc in range(total_pcs): 
        eig = eigens[0,pc]
        if eig > 0: 
            pos_pcs.append(pc)
    if len(pos_pcs) == 0: 
        return 0, 0, pos_pcs
    X = acpca_data[:,pos_pcs]
    Y = combined_data['normalized_deaths']
    reg = lm.LinearRegression().fit(X,Y)
    final_score = reg.score(X,Y)
    coeffs = {}
    for i in range(len(pos_pcs)): 
        coeffs[pos_pcs[i]] = reg.coef_[i]
    return final_score, coeffs, pos_pcs

# %% [markdown]
# ## Calculate individual weight of each variable

# %%
def calc_weights(coeffs, pos_pcs, ind_vars):
    weights = {}
    r,c = PCs.shape
    for pc in pos_pcs: 
        eig = eigens[0, pc]
        PC_dict = {}
        # PC9 = [-0.190896056547888, 0.468236937317933,-0.228567222005448,0.408002822993487,0.0535105125245226,0.407238079363182,0.181820228133276,0.366604933989350,0.435246581102968]
        for i in range(r): 
        #     print('{0:<80} \t {1:>0.3f}'.format(combined_data.columns.values[i+2], PC9[i]))
            loading = PCs[i,pc] # weight of variable in component
            variable = ind_vars[i] # variable name in column headers 
            PC_dict[variable] = loading
            coef = coeffs[pc] # coefficient corresponding to PC
            if variable not in weights:
                weights[variable] = 0
            weights[variable] += coef * loading
    return weights

# %% [markdown]
# ## Print results and identify strongest variable

# %%
def results(weights, final_score, mobility_features):
    print('score:', final_score)
    max_weight_mag = np.max(np.abs(np.array(list(weights.values()))))
    max_weight = 0
    max_var = None
    max_mobility_weight = 0
    max_mobility_var = None
    for var, weight in weights.items():
        if var in mobility_features and weight > max_mobility_weight:
            max_mobility_weight = weight
            max_mobility_var = var
    #     print('{0:<100} & {1:>0.4f} \\\\ \hline'.format(var.replace('_', '\\_'), weight))
        if abs(weight) == max_weight_mag: 
            max_weight = weight
            max_var = var
            print('*** {0:<100} {1:>0.4f}'.format(var, weight))
        else:
            print('{0:<100} {1:>0.4f}'.format(var, weight))
    print('\n\nmax var: ', max_var)
    return max_var, max_weight, max_mobility_var, max_mobility_weight

# %%
mobility_features = ['inter_movement', 'out_movement', 'baseline m50 mobility']
confounders = {} 
it = 0 
while len(confounders) < total_vars - 1:
    print('Iteration', it)
    print('confounders:', *confounders.keys())
    it += 1
    acpca_data, PCs, eigens, column_names, ind_vars = run_acpca(combined_data, confounders)
    final_score, coeffs, pos_pcs = linreg_coeffs(combined_data, acpca_data, eigens)
    if len(pos_pcs) == 0: 
        print('\n\n\n')
        break 
    weights = calc_weights(coeffs, pos_pcs, ind_vars)
    max_var, max_weight, max_mobility_var, max_mobility_weight = results(weights, final_score, mobility_features)
    confounders[max_var] = max_weight
    print('\n\n\n')
for var, weight in confounders.items():
    print('{0:<100} & {1:>0.4f} \\\\hline'.format(var, weight))
# Out:
# Iteration 0
# confounders:
# score: 0.7126282820759555
# 2wk Prior Mobility                                                                                   -0.0030
# 2wk Onset Mobility                                                                                   0.0700
# 2wk Post Mobility                                                                                    -0.0806
# inter_movement                                                                                       0.0320
# out_movement                                                                                         0.0726
# baseline m50 mobility                                                                                0.0371
# *** Density per square mile of land area - Population                                                    0.9506
# Rural-urban_Continuum Code_2013                                                                      0.0597
# Percent of adults with less than a high school diploma 2014-18                                       -0.0041
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0092
# Unemployment_rate_2018                                                                               0.0350
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0499
# Total_age65plus                                                                                      0.2064
# Total households!!Average household size                                                             0.0131
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0459
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      0.0136
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    0.0601
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0439
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0576
# HospCt                                                                                               0.0347
# Longterm HospCt                                                                                      -0.0162
# Hispanic Population                                                                                  -0.0082
# Black Population                                                                                     0.0242
# Outbreak Month Temp AVG / F                                                                          -0.0652
# Time from outbreak to intervention                                                                   -0.0892
# Time from outbreak to national intervention                                                          0.1256
#
#
# max var:  Density per square mile of land area - Population
#
#
#
#
# Iteration 1
# confounders: Density per square mile of land area - Population
# score: 0.1460589192558912
# 2wk Prior Mobility                                                                                   0.0067
# 2wk Onset Mobility                                                                                   0.0835
# 2wk Post Mobility                                                                                    -0.0966
# inter_movement                                                                                       0.0240
# out_movement                                                                                         0.0808
# baseline m50 mobility                                                                                0.0199
# Rural-urban_Continuum Code_2013                                                                      0.0507
# Percent of adults with less than a high school diploma 2014-18                                       0.0152
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0320
# Unemployment_rate_2018                                                                               0.0340
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0453
# *** Total_age65plus                                                                                      0.1846
# Total households!!Average household size                                                             0.0052
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0457
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      0.0066
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    0.0418
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0314
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0492
# HospCt                                                                                               0.0367
# Longterm HospCt                                                                                      -0.0171
# Hispanic Population                                                                                  -0.0053
# Black Population                                                                                     0.0277
# Outbreak Month Temp AVG / F                                                                          -0.0688
# Time from outbreak to intervention                                                                   -0.0781
# Time from outbreak to national intervention                                                          0.1282
#
#
# max var:  Total_age65plus
#
#
#
#
# Iteration 2
# confounders: Density per square mile of land area - Population Total_age65plus
# score: 0.12195923548424992
# 2wk Prior Mobility                                                                                   0.0086
# 2wk Onset Mobility                                                                                   0.0376
# 2wk Post Mobility                                                                                    -0.0604
# inter_movement                                                                                       0.0208
# out_movement                                                                                         0.0648
# baseline m50 mobility                                                                                0.0257
# Rural-urban_Continuum Code_2013                                                                      0.0670
# Percent of adults with less than a high school diploma 2014-18                                       -0.0199
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0105
# Unemployment_rate_2018                                                                               0.0530
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0544
# Total households!!Average household size                                                             0.0112
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0357
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0079
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0344
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0364
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0048
# HospCt                                                                                               0.0389
# Longterm HospCt                                                                                      -0.0140
# Hispanic Population                                                                                  -0.0066
# Black Population                                                                                     0.0098
# Outbreak Month Temp AVG / F                                                                          -0.0477
# Time from outbreak to intervention                                                                   -0.0830
# *** Time from outbreak to national intervention                                                          0.1412
#
#
# max var:  Time from outbreak to national intervention
#
#
#
#
# Iteration 3
# confounders: Density per square mile of land area - Population Total_age65plus Time from outbreak to national intervention
# score: 0.10198605477371882
# 2wk Prior Mobility                                                                                   0.0252
# 2wk Onset Mobility                                                                                   0.0094
# 2wk Post Mobility                                                                                    -0.0402
# inter_movement                                                                                       0.0141
# *** out_movement                                                                                         0.0652
# baseline m50 mobility                                                                                0.0215
# Rural-urban_Continuum Code_2013                                                                      0.0651
# Percent of adults with less than a high school diploma 2014-18                                       -0.0137
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0225
# Unemployment_rate_2018                                                                               0.0499
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0517
# Total households!!Average household size                                                             0.0211
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0337
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0099
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0360
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0291
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0070
# HospCt                                                                                               0.0407
# Longterm HospCt                                                                                      -0.0150
# Hispanic Population                                                                                  -0.0062
# Black Population                                                                                     0.0173
# Outbreak Month Temp AVG / F                                                                          -0.0460
# Time from outbreak to intervention                                                                   0.0096
#
#
# max var:  out_movement
#
#
#
#
# Iteration 4
# confounders: Density per square mile of land area - Population Total_age65plus Time from outbreak to national intervention out_movement
# score: 0.0798377925570769
# 2wk Prior Mobility                                                                                   0.0257
# 2wk Onset Mobility                                                                                   0.0206
# 2wk Post Mobility                                                                                    -0.0528
# inter_movement                                                                                       -0.0247
# baseline m50 mobility                                                                                0.0356
# *** Rural-urban_Continuum Code_2013                                                                      0.0547
# Percent of adults with less than a high school diploma 2014-18                                       0.0109
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0271
# Unemployment_rate_2018                                                                               0.0429
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0388
# Total households!!Average household size                                                             0.0140
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0405
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0094
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0359
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0315
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0002
# HospCt                                                                                               0.0424
# Longterm HospCt                                                                                      -0.0123
# Hispanic Population                                                                                  -0.0123
# Black Population                                                                                     0.0202
# Outbreak Month Temp AVG / F                                                                          -0.0507
# Time from outbreak to intervention                                                                   -0.0020
#
#
# max var:  Rural-urban_Continuum Code_2013
#
#
#
#
# Iteration 5
# confounders: Density per square mile of land area - Population Total_age65plus Time from outbreak to national intervention out_movement Rural-urban_Continuum Code_2013
# score: 0.053031434949196266
# 2wk Prior Mobility                                                                                   0.0163
# 2wk Onset Mobility                                                                                   -0.0040
# 2wk Post Mobility                                                                                    -0.0403
# inter_movement                                                                                       0.0181
# baseline m50 mobility                                                                                0.0296
# Percent of adults with less than a high school diploma 2014-18                                       -0.0359
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0123
# *** Unemployment_rate_2018                                                                               0.0523
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0522
# Total households!!Average household size                                                             0.0223
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0330
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0109
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0522
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0298
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0219
# HospCt                                                                                               0.0329
# Longterm HospCt                                                                                      -0.0148
# Hispanic Population                                                                                  0.0096
# Black Population                                                                                     0.0239
# Outbreak Month Temp AVG / F                                                                          -0.0483
# Time from outbreak to intervention                                                                   -0.0280
#
#
# max var:  Unemployment_rate_2018
#
#
#
#
# Iteration 6
# confounders: Density per square mile of land area - Population Total_age65plus Time from outbreak to national intervention out_movement Rural-urban_Continuum Code_2013 Unemployment_rate_2018
# score: 0.048095187512612436
# 2wk Prior Mobility                                                                                   0.0132
# 2wk Onset Mobility                                                                                   -0.0043
# 2wk Post Mobility                                                                                    -0.0387
# inter_movement                                                                                       0.0179
# baseline m50 mobility                                                                                0.0223
# Percent of adults with less than a high school diploma 2014-18                                       -0.0289
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0062
# *** Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0587
# Total households!!Average household size                                                             0.0272
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0320
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0124
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0516
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0332
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0234
# HospCt                                                                                               0.0366
# Longterm HospCt                                                                                      -0.0138
# Hispanic Population                                                                                  0.0049
# Black Population                                                                                     0.0206
# Outbreak Month Temp AVG / F                                                                          -0.0456
# Time from outbreak to intervention                                                                   -0.0236
#
#
# max var:  Med_HH_Income_Percent_of_State_Total_2018
#
#
#
#
# Iteration 7
# confounders: Density per square mile of land area - Population Total_age65plus Time from outbreak to national intervention out_movement Rural-urban_Continuum Code_2013 Unemployment_rate_2018 Med_HH_Income_Percent_of_State_Total_2018
# score: 0.04059811472779229
# 2wk Prior Mobility                                                                                   0.0051
# 2wk Onset Mobility                                                                                   -0.0052
# 2wk Post Mobility                                                                                    -0.0319
# inter_movement                                                                                       0.0257
# baseline m50 mobility                                                                                -0.0037
# Percent of adults with less than a high school diploma 2014-18                                       -0.0209
# Percent of adults with a bachelor's degree or higher 2014-18                                         -0.0235
# Total households!!Average household size                                                             0.0297
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0294
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0173
# *** SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0569
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0394
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0233
# HospCt                                                                                               0.0428
# Longterm HospCt                                                                                      -0.0096
# Hispanic Population                                                                                  0.0017
# Black Population                                                                                     0.0161
# Outbreak Month Temp AVG / F                                                                          -0.0438
# Time from outbreak to intervention                                                                   -0.0231
#
#
# max var:  SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)
#
#
#
#
# Iteration 8
# confounders: Density per square mile of land area - Population Total_age65plus Time from outbreak to national intervention out_movement Rural-urban_Continuum Code_2013 Unemployment_rate_2018 Med_HH_Income_Percent_of_State_Total_2018 SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)
# score: 0.04428394433351823
# 2wk Prior Mobility                                                                                   -0.0301
# 2wk Onset Mobility                                                                                   0.1315
# *** 2wk Post Mobility                                                                                    -0.1463
# inter_movement                                                                                       0.0127
# baseline m50 mobility                                                                                0.0050
# Percent of adults with less than a high school diploma 2014-18                                       -0.0296
# Percent of adults with a bachelor's degree or higher 2014-18                                         -0.0209
# Total households!!Average household size                                                             -0.0092
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0179
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0287
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0148
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0269
# HospCt                                                                                               0.0305
# Longterm HospCt                                                                                      0.0015
# Hispanic Population                                                                                  0.0109
# Black Population                                                                                     0.0164
# Outbreak Month Temp AVG / F                                                                          -0.0422
# Time from outbreak to intervention                                                                   -0.0021
#
#
# max var:  2wk Post Mobility
#
#
#
#
# Iteration 9
# confounders: Density per square mile of land area - Population Total_age65plus Time from outbreak to national intervention out_movement Rural-urban_Continuum Code_2013 Unemployment_rate_2018 Med_HH_Income_Percent_of_State_Total_2018 SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8) 2wk Post Mobility
# score: 0.028688471425908024
# 2wk Prior Mobility                                                                                   0.0142
# 2wk Onset Mobility                                                                                   0.0124
# inter_movement                                                                                       -0.0145
# baseline m50 mobility                                                                                -0.0076
# Percent of adults with less than a high school diploma 2014-18                                       -0.0325
# Percent of adults with a bachelor's degree or higher 2014-18                                         -0.0105
# Total households!!Average household size                                                             -0.0001
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0189
# *** SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0426
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0203
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0172
# HospCt                                                                                               0.0230
# Longterm HospCt                                                                                      0.0162
# Hispanic Population                                                                                  0.0118
# Black Population                                                                                     0.0192
# Outbreak Month Temp AVG / F                                                                          -0.0338
# Time from outbreak to intervention                                                                   -0.0251
#
#
# max var:  SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten
#
#
#
#
# Iteration 10
# confounders: Density per square mile of land area - Population Total_age65plus Time from outbreak to national intervention out_movement Rural-urban_Continuum Code_2013 Unemployment_rate_2018 Med_HH_Income_Percent_of_State_Total_2018 SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8) 2wk Post Mobility SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten
# score: 0.02021635486733575
# 2wk Prior Mobility                                                                                   0.0292
# 2wk Onset Mobility                                                                                   0.0116
# inter_movement                                                                                       -0.0395
# baseline m50 mobility                                                                                -0.0254
# *** Percent of adults with less than a high school diploma 2014-18                                       -0.0445
# Percent of adults with a bachelor's degree or higher 2014-18                                         -0.0145
# Total households!!Average household size                                                             -0.0266
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0145
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0289
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0129
# HospCt                                                                                               0.0159
# Longterm HospCt                                                                                      -0.0082
# Hispanic Population                                                                                  0.0202
# Black Population                                                                                     0.0129
# Outbreak Month Temp AVG / F                                                                          -0.0141
# Time from outbreak to intervention                                                                   -0.0110
#
#
# max var:  Percent of adults with less than a high school diploma 2014-18
#
#
#
#
# Iteration 11
# confounders: Density per square mile of land area - Population Total_age65plus Time from outbreak to national intervention out_movement Rural-urban_Continuum Code_2013 Unemployment_rate_2018 Med_HH_Income_Percent_of_State_Total_2018 SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8) 2wk Post Mobility SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten Percent of adults with less than a high school diploma 2014-18
# score: 0.056374936282373
# 2wk Prior Mobility                                                                                   0.0625
# 2wk Onset Mobility                                                                                   -0.0141
# inter_movement                                                                                       -0.0224
# baseline m50 mobility                                                                                0.0354
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0135
# Total households!!Average household size                                                             -0.0433
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0286
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         -0.0124
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0432
# *** HospCt                                                                                               0.0684
# Longterm HospCt                                                                                      -0.0255
# Hispanic Population                                                                                  0.0405
# Black Population                                                                                     0.0260
# Outbreak Month Temp AVG / F                                                                          -0.0444
# Time from outbreak to intervention                                                                   -0.0324
#
#
# max var:  HospCt
#
#
#
#
# Iteration 12
# confounders: Density per square mile of land area - Population Total_age65plus Time from outbreak to national intervention out_movement Rural-urban_Continuum Code_2013 Unemployment_rate_2018 Med_HH_Income_Percent_of_State_Total_2018 SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8) 2wk Post Mobility SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten Percent of adults with less than a high school diploma 2014-18 HospCt
# score: 0.023089195243736538
# *** 2wk Prior Mobility                                                                                   0.0913
# 2wk Onset Mobility                                                                                   -0.0022
# inter_movement                                                                                       -0.0664
# baseline m50 mobility                                                                                0.0167
# Percent of adults with a bachelor's degree or higher 2014-18                                         -0.0022
# Total households!!Average household size                                                             -0.0107
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0312
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         -0.0101
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0144
# Longterm HospCt                                                                                      0.0081
# Hispanic Population                                                                                  0.0039
# Black Population                                                                                     -0.0195
# Outbreak Month Temp AVG / F                                                                          -0.0033
# Time from outbreak to intervention                                                                   0.0022
#
#
# max var:  2wk Prior Mobility
#
#
#
#
# Iteration 13
# confounders: Density per square mile of land area - Population Total_age65plus Time from outbreak to national intervention out_movement Rural-urban_Continuum Code_2013 Unemployment_rate_2018 Med_HH_Income_Percent_of_State_Total_2018 SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8) 2wk Post Mobility SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten Percent of adults with less than a high school diploma 2014-18 HospCt 2wk Prior Mobility
# score: 0.0044352301859609256
# 2wk Onset Mobility                                                                                   0.0007
# inter_movement                                                                                       -0.0023
# baseline m50 mobility                                                                                0.0074
# Percent of adults with a bachelor's degree or higher 2014-18                                         -0.0084
# Total households!!Average household size                                                             -0.0134
# *** SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0243
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         -0.0091
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0025
# Longterm HospCt                                                                                      0.0076
# Hispanic Population                                                                                  0.0126
# Black Population                                                                                     -0.0123
# Outbreak Month Temp AVG / F                                                                          -0.0060
# Time from outbreak to intervention                                                                   -0.0033
#
#
# max var:  SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool
#
#
#
#
# Iteration 14
# confounders: Density per square mile of land area - Population Total_age65plus Time from outbreak to national intervention out_movement Rural-urban_Continuum Code_2013 Unemployment_rate_2018 Med_HH_Income_Percent_of_State_Total_2018 SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8) 2wk Post Mobility SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten Percent of adults with less than a high school diploma 2014-18 HospCt 2wk Prior Mobility SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool
# score: 0.01913780284365252
# 2wk Onset Mobility                                                                                   0.0183
# inter_movement                                                                                       -0.0085
# baseline m50 mobility                                                                                0.0114
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0111
# Total households!!Average household size                                                             -0.0043
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         -0.0115
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0206
# Longterm HospCt                                                                                      0.0186
# Hispanic Population                                                                                  0.0314
# Black Population                                                                                     -0.0077
# *** Outbreak Month Temp AVG / F                                                                          -0.0412
# Time from outbreak to intervention                                                                   -0.0329
#
#
# max var:  Outbreak Month Temp AVG / F
#
#
#
#
# Iteration 15
# confounders: Density per square mile of land area - Population Total_age65plus Time from outbreak to national intervention out_movement Rural-urban_Continuum Code_2013 Unemployment_rate_2018 Med_HH_Income_Percent_of_State_Total_2018 SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8) 2wk Post Mobility SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten Percent of adults with less than a high school diploma 2014-18 HospCt 2wk Prior Mobility SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool Outbreak Month Temp AVG / F
#
#
#
#
# Density per square mile of land area - Population                                                    & 0.9506 \\hline
# Total_age65plus                                                                                      & 0.1846 \\hline
# Time from outbreak to national intervention                                                          & 0.1412 \\hline
# out_movement                                                                                         & 0.0652 \\hline
# Rural-urban_Continuum Code_2013                                                                      & 0.0547 \\hline
# Unemployment_rate_2018                                                                               & 0.0523 \\hline
# Med_HH_Income_Percent_of_State_Total_2018                                                            & -0.0587 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    & -0.0569 \\hline
# 2wk Post Mobility                                                                                    & -0.1463 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      & -0.0426 \\hline
# Percent of adults with less than a high school diploma 2014-18                                       & -0.0445 \\hline
# HospCt                                                                                               & 0.0684 \\hline
# 2wk Prior Mobility                                                                                   & 0.0913 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          & 0.0243 \\hline
# Outbreak Month Temp AVG / F                                                                          & -0.0412 \\hline

# %% [raw]
# problems: 2wk mobility averages and time from outbreak to intervention should all be positive

# %% [raw]
# interventon date - outbreak
# neg if intervention happens before outbreak (neg in most cases)
# pos if outbreak before intervention
# 0 if same day

# %% [raw]
# Density per square mile of land area - Population                                                    & 0.9555 \\hline
# Total_age65plus                                                                                      & 0.1959 \\hline
# Outbreak Month Temp AVG / F                                                                          & -0.0657 \\hline
# 2wk Onset Mobility                                                                                   & -0.0979 \\hline
# Med_HH_Income_Percent_of_State_Total_2018                                                            & -0.0781 \\hline
# Unemployment_rate_2018                                                                               & 0.0741 \\hline
# out_movement                                                                                         & 0.0518 \\hline
# HospCt                                                                                               & 0.0385 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          & 0.0370 \\hline
# 2wk Prior Mobility                                                                                   & 0.0398 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         & 0.0259 \\hline
# Time from outbreak to intervention                                                                   & -0.0179 \\hline
# Rural-urban_Continuum Code_2013                                                                      & 0.0084 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      & 0.0095 \\hline

# %% [raw]
# After fixing intervention to be school closing, Longterm still negative
#
# Density per square mile of land area - Population                                                    & 0.9494 \\hline
# Total_age65plus                                                                                      & 0.1896 \\hline
# Rural-urban_Continuum Code_2013                                                                      & 0.0652 \\hline
# Unemployment_rate_2018                                                                               & 0.0647 \\hline
# Med_HH_Income_Percent_of_State_Total_2018                                                            & -0.0655 \\hline
# HospCt                                                                                               & 0.0644 \\hline
# Hispanic Population                                                                                  & -0.0456 \\hline
# 2wk Onset Mobility                                                                                   & -0.0825 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    & -0.0500 \\hline
# Black Population                                                                                     & -0.0399 \\hline
# baseline m50 mobility                                                                                & 0.0197 \\hline
# inter_movement                                                                                       & 0.0195 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      & -0.0145 \\hline
# Total households!!Average household size                                                             & 0.0047 \\hline

# %% [raw]
# W/o age 65+ and w/o HospCt but w/o fixing intervention to be school closing
#
# Density per square mile of land area - Population                                                    & 0.9183 \\hline
# Outbreak Month Temp AVG / F                                                                          & -0.0678 \\hline
# 2wk Onset Mobility                                                                                   & -0.0996 \\hline
# Med_HH_Income_Percent_of_State_Total_2018                                                            & -0.0760 \\hline
# Unemployment_rate_2018                                                                               & 0.0744 \\hline
# out_movement                                                                                         & 0.0534 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         & 0.0378 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          & 0.0366 \\hline
# 2wk Prior Mobility                                                                                   & 0.0326 \\hline
# Hispanic Population                                                                                  & -0.0246 \\hline
# Total households!!Average household size                                                             & -0.0479 \\hline
# Longterm HospCt                                                                                      & -0.0231 \\hline
# Time from outbreak to intervention                                                                   & -0.0189 \\hline

# %% [raw]
# W/o age 65+ and w/o HospCt after fixing intervention to be school closing
#
# Density per square mile of land area - Population                                                    & 0.9120 \\hline
# Rural-urban_Continuum Code_2013                                                                      & 0.0701 \\hline
# Unemployment_rate_2018                                                                               & 0.0622 \\hline
# Hispanic Population                                                                                  & -0.0603 \\hline
# Med_HH_Income_Percent_of_State_Total_2018                                                            & -0.0555 \\hline
# 2wk Onset Mobility                                                                                   & -0.0540 \\hline
# Outbreak Month Temp AVG / F                                                                          & -0.0392 \\hline
# Total households!!Average household size                                                             & -0.0444 \\hline
# out_movement                                                                                         & 0.0566 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    & -0.0427 \\hline
# Longterm HospCt                                                                                      & 0.0224 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          & 0.0229 \\hline
# 2wk Prior Mobility                                                                                   & 0.1008 \\hline

# %% [raw]
# W/o age 65+ after fixing intervention to be school closing, Longterm HospCt is negative but does not come out as significant variable
#
# Density per square mile of land area - Population                                                    & 0.9096 \\hline
# Rural-urban_Continuum Code_2013                                                                      & 0.0645 \\hline
# Med_HH_Income_Percent_of_State_Total_2018                                                            & -0.0619 \\hline
# Unemployment_rate_2018                                                                               & 0.0671 \\hline
# HospCt                                                                                               & 0.0655 \\hline
# Hispanic Population                                                                                  & -0.0480 \\hline
# 2wk Onset Mobility                                                                                   & -0.0610 \\hline
# Outbreak Month Temp AVG / F                                                                          & -0.0379 \\hline
# Total households!!Average household size                                                             & -0.0399 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    & -0.0500 \\hline
# out_movement                                                                                         & 0.0444 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          & 0.0184 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      & -0.0114 \\hline
# 2wk Prior Mobility                                                                                   & 0.0946 \\hline

# %% [raw]
# w/o HospCt after fixing intervention to be school closing
#
# Density per square mile of land area - Population                                                    & 0.9520 \\hline
# Total_age65plus                                                                                      & 0.1906 \\hline
# Rural-urban_Continuum Code_2013                                                                      & 0.0708 \\hline
# Unemployment_rate_2018                                                                               & 0.0650 \\hline
# Med_HH_Income_Percent_of_State_Total_2018                                                            & -0.0618 \\hline
# Hispanic Population                                                                                  & -0.0479 \\hline
# 2wk Onset Mobility                                                                                   & -0.0790 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    & -0.0521 \\hline
# Black Population                                                                                     & -0.0400 \\hline
# baseline m50 mobility                                                                                & 0.0257 \\hline
# Longterm HospCt                                                                                      & 0.0223 \\hline
# inter_movement                                                                                       & 0.0157 \\hline
# Total households!!Average household size                                                             & 0.0099 \\hline

# %% [raw]
# Longterm HospCt only positive if intervnetion is school closure and HospCt is removed- same result with or w/o age 65 plus

# %% [raw]
# After adding time to March 19, when the State Department issued a Level 4 “do not travel” advisory, recommending that United States citizens avoid any global travel. This is the highest travel advisory the federal agency can issue.
#
# Density per square mile of land area - Population                                                    & 0.9506 \\hline
# Total_age65plus                                                                                      & 0.1846 \\hline
# Time from outbreak to national intervention                                                          & 0.1412 \\hline
# out_movement                                                                                         & 0.0652 \\hline
# Rural-urban_Continuum Code_2013                                                                      & 0.0547 \\hline
# Unemployment_rate_2018                                                                               & 0.0523 \\hline
# Med_HH_Income_Percent_of_State_Total_2018                                                            & -0.0587 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    & -0.0569 \\hline
# 2wk Post Mobility                                                                                    & -0.1463 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      & -0.0426 \\hline
# Percent of adults with less than a high school diploma 2014-18                                       & -0.0445 \\hline
# HospCt                                                                                               & 0.0684 \\hline
# 2wk Prior Mobility                                                                                   & 0.0913 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          & 0.0243 \\hline
# Outbreak Month Temp AVG / F                                                                          & -0.0412 \\hline
