# %% [raw]
# Beatriz Medeiros
# Notebook for AC-PCA on independent and dependent variables separately

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.linear_model as lm
from collections import defaultdict
import sys; sys.path.append('../')
from src.data_analysis.tools import ac_pca

# %% [markdown]
# ## Get Preprocessed data

# %%
combined_data = pd.read_csv('../data/intermediates/pre_acpca1.csv')
combined_data.set_index('FIPS', inplace=True)
print(combined_data.shape)
ind_vars = list(combined_data.columns)
total_vars = len(ind_vars)
combined_data.head()
# Out:
# (489, 25)
#       2wk Prior Mobility  2wk Onset Mobility  2wk Post Mobility  \
# FIPS
# 1003            1.576073            0.855816           0.878907
# 1051            1.589227            0.827146           0.482122
# 1055            1.648708            0.871093           0.894249
# 1073            1.616364            0.854042           0.873638
# 1081            1.308183            0.655494           0.697297
#
#       inter_movement  out_movement  baseline m50 mobility  \
# FIPS
# 1003        0.519349      0.244188               0.610171
# 1051        0.452205      0.745075               0.840246
# 1055        0.677227      0.378689               0.449395
# 1073        0.775948      0.190299               0.483877
# 1081        0.572121      0.464994               0.307942
#
#       Density per square mile of land area - Population  \
# FIPS
# 1003                                           0.001558
# 1051                                           0.001753
# 1055                                           0.002718
# 1073                                           0.008438
# 1081                                           0.003231
#
#       Rural-urban_Continuum Code_2013  \
# FIPS
# 1003                              0.4
# 1051                              0.2
# 1055                              0.4
# 1073                              0.0
# 1081                              0.4
#
#       Percent of adults with less than a high school diploma 2014-18  \
# FIPS
# 1003                                           0.229851
# 1051                                           0.346269
# 1055                                           0.402985
# 1073                                           0.247761
# 1081                                           0.223881
#
#       Percent of adults with a bachelor's degree or higher 2014-18  ...  \
# FIPS                                                                ...
# 1003                                           0.312698             ...
# 1051                                           0.204762             ...
# 1055                                           0.096825             ...
# 1073                                           0.330159             ...
# 1081                                           0.357143             ...
#
#       SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten  \
# FIPS
# 1003                                           0.129585
# 1051                                           0.130406
# 1055                                           0.358494
# 1073                                           0.386817
# 1081                                           0.144048
#
#       SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)  \
# FIPS
# 1003                                           0.627997
# 1051                                           0.487643
# 1055                                           0.567540
# 1073                                           0.576102
# 1081                                           0.571650
#
#       SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)  \
# FIPS
# 1003                                           0.462848
# 1051                                           0.645915
# 1055                                           0.360599
# 1073                                           0.416900
# 1081                                           0.442769
#
#       SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school  \
# FIPS
# 1003                                           0.038455
# 1051                                           0.113909
# 1055                                           0.075155
# 1073                                           0.172229
# 1081                                           0.609583
#
#         HospCt  Hispanic Population  Black Population  \
# FIPS
# 1003  0.170836             0.038549          0.116681
# 1051  0.338853             0.021248          0.290098
# 1055  0.261462             0.031866          0.210358
# 1073  0.169115             0.031499          0.594907
# 1081  0.050141             0.029159          0.312716
#
#       Outbreak Month Temp AVG / F    Deaths  normalized_deaths
# FIPS
# 1003                     0.952015  0.000789           0.010689
# 1051                     0.923225  0.000789           0.032762
# 1055                     0.689060  0.000986           0.028791
# 1073                     0.694818  0.005521           0.013511
# 1081                     0.704415  0.003943           0.046459
#
# [5 rows x 25 columns]

# %%
ind_vars
# Out:
# ['2wk Prior Mobility',
#  '2wk Onset Mobility',
#  '2wk Post Mobility',
#  'inter_movement',
#  'out_movement',
#  'baseline m50 mobility',
#  'Density per square mile of land area - Population',
#  'Rural-urban_Continuum Code_2013',
#  'Percent of adults with less than a high school diploma 2014-18',
#  "Percent of adults with a bachelor's degree or higher 2014-18",
#  'Unemployment_rate_2018',
#  'Med_HH_Income_Percent_of_State_Total_2018',
#  'Total_age65plus',
#  'Total households!!Average household size',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school',
#  'HospCt',
#  'Hispanic Population',
#  'Black Population',
#  'Outbreak Month Temp AVG / F',
#  'Deaths',
#  'normalized_deaths']

# %% [markdown]
# ## Run AC-PCA

# %%
def run_acpca(combined_data, confounders):
    ind_vars = list(combined_data.drop(columns=confounders).columns)
    X = combined_data.drop(columns=['Deaths', 'normalized_deaths'], inplace=False)
    X = X.drop(columns=confounders, inplace=False).to_numpy() # 'Density per square mile of land area - Population',
#     print(X.shape)
    X_rows, X_cols = X.shape
    column_names = ['PC' + str(i) for i in range(1, X_cols + 1)]
    if len(confounders) > 0: 
        Y = combined_data.filter(confounders).to_numpy()
    else: 
        Y = np.zeros((X_rows))
    if len(Y.shape) < 2: 
        Y = Y.reshape(len(Y), 1)
    acpca_data, PCs, eigens = ac_pca(X, Y)
    acpca_data = acpca_data.to_numpy()
    PCs = PCs.to_numpy()
    eigens = eigens.to_numpy()
    return acpca_data, PCs, eigens, column_names, ind_vars

# %% [markdown]
# ## Run linear regression on all PCs and get coefficients

# %%
def linreg_coeffs(combined_data, acpca_data, eigens):   
    _, total_pcs = eigens.shape
    pos_pcs = []
    for pc in range(total_pcs): 
        eig = eigens[0,pc]
        if eig > 0: 
            pos_pcs.append(pc)
    if len(pos_pcs) == 0: 
        return 0, 0, pos_pcs
    X = acpca_data[:,pos_pcs]
    Y = combined_data['normalized_deaths']
    reg = lm.LinearRegression().fit(X,Y)
    final_score = reg.score(X,Y)
    coeffs = {}
    for i in range(len(pos_pcs)): 
        coeffs[pos_pcs[i]] = reg.coef_[i]
    return final_score, coeffs, pos_pcs

# %% [markdown]
# ## Calculate individual weight of each variable

# %%
def calc_weights(coeffs, pos_pcs, ind_vars):
    weights = {}
    r,c = PCs.shape
    for pc in pos_pcs: 
        eig = eigens[0, pc]
        PC_dict = {}
        # PC9 = [-0.190896056547888, 0.468236937317933,-0.228567222005448,0.408002822993487,0.0535105125245226,0.407238079363182,0.181820228133276,0.366604933989350,0.435246581102968]
        for i in range(r): 
        #     print('{0:<80} \t {1:>0.3f}'.format(combined_data.columns.values[i+2], PC9[i]))
            loading = PCs[i,pc] # weight of variable in component
            variable = ind_vars[i] # variable name in column headers 
            PC_dict[variable] = loading
            coef = coeffs[pc] # coefficient corresponding to PC
            if variable not in weights:
                weights[variable] = 0
            weights[variable] += coef * loading
    return weights

# %% [markdown]
# ## Print results and identify strongest variable

# %%
def results(weights, final_score, mobility_features):
    print('score:', final_score)
    max_weight_mag = np.max(np.abs(np.array(list(weights.values()))))
    max_weight = 0
    max_var = None
    max_mobility_weight = 0
    max_mobility_var = None
    for var, weight in weights.items():
        if var in mobility_features and weight > max_mobility_weight:
            max_mobility_weight = weight
            max_mobility_var = var
    #     print('{0:<100} & {1:>0.4f} \\\\ \hline'.format(var.replace('_', '\\_'), weight))
        if abs(weight) == max_weight_mag: 
            max_weight = weight
            max_var = var
            print('*** {0:<100} {1:>0.4f}'.format(var, weight))
        else:
            print('{0:<100} {1:>0.4f}'.format(var, weight))
    print('\n\nmax var: ', max_var)
    return max_var, max_weight, max_mobility_var, max_mobility_weight

# %%
mobility_features = ['inter_movement', 'out_movement', 'baseline m50 mobility']
confounders = {} 
it = 0 
while len(confounders) < total_vars - 1:
    print('Iteration', it)
    print('confounders:', *confounders.keys())
    it += 1
    acpca_data, PCs, eigens, column_names, ind_vars = run_acpca(combined_data, confounders)
    final_score, coeffs, pos_pcs = linreg_coeffs(combined_data, acpca_data, eigens)
    if len(pos_pcs) == 0: 
        print('\n\n\n')
        break 
    weights = calc_weights(coeffs, pos_pcs, ind_vars)
    max_var, max_weight, max_mobility_var, max_mobility_weight = results(weights, final_score, mobility_features)
    confounders[max_var] = max_weight
    print('\n\n\n')
for var, weight in confounders.items():
    print('{0:<100} & {1:>0.4f} \\\\hline'.format(var, weight))
# Out:
# Iteration 0
# confounders:
# score: 0.6513379867844611
# 2wk Prior Mobility                                                                                   0.0409
# 2wk Onset Mobility                                                                                   -0.0215
# 2wk Post Mobility                                                                                    -0.0151
# inter_movement                                                                                       0.0110
# out_movement                                                                                         0.0884
# baseline m50 mobility                                                                                0.0305
# *** Density per square mile of land area - Population                                                    0.9277
# Rural-urban_Continuum Code_2013                                                                      0.0472
# Percent of adults with less than a high school diploma 2014-18                                       0.0278
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0136
# Unemployment_rate_2018                                                                               0.0460
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0314
# Total_age65plus                                                                                      0.1770
# Total households!!Average household size                                                             0.0300
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0431
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0043
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    0.0527
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0148
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0435
# HospCt                                                                                               0.0381
# Hispanic Population                                                                                  -0.0185
# Black Population                                                                                     0.0246
# Outbreak Month Temp AVG / F                                                                          -0.0887
#
#
# max var:  Density per square mile of land area - Population
#
#
#
#
# Iteration 1
# confounders: Density per square mile of land area - Population
# score: 0.14685236087868347
# 2wk Prior Mobility                                                                                   0.0448
# 2wk Onset Mobility                                                                                   -0.0232
# 2wk Post Mobility                                                                                    -0.0178
# inter_movement                                                                                       0.0105
# out_movement                                                                                         0.0897
# baseline m50 mobility                                                                                0.0216
# Rural-urban_Continuum Code_2013                                                                      0.0392
# Percent of adults with less than a high school diploma 2014-18                                       0.0311
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0250
# Unemployment_rate_2018                                                                               0.0450
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0286
# *** Total_age65plus                                                                                      0.1739
# Total households!!Average household size                                                             0.0268
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0443
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0078
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    0.0458
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0070
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0429
# HospCt                                                                                               0.0367
# Hispanic Population                                                                                  -0.0139
# Black Population                                                                                     0.0292
# Outbreak Month Temp AVG / F                                                                          -0.0952
#
#
# max var:  Total_age65plus
#
#
#
#
# Iteration 2
# confounders: Density per square mile of land area - Population Total_age65plus
# score: 0.1275656536686719
# 2wk Prior Mobility                                                                                   0.0345
# 2wk Onset Mobility                                                                                   -0.0433
# 2wk Post Mobility                                                                                    0.0001
# inter_movement                                                                                       0.0123
# out_movement                                                                                         0.0729
# baseline m50 mobility                                                                                0.0269
# Rural-urban_Continuum Code_2013                                                                      0.0501
# Percent of adults with less than a high school diploma 2014-18                                       0.0087
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0108
# Unemployment_rate_2018                                                                               0.0635
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0380
# Total households!!Average household size                                                             0.0354
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0346
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0220
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0202
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0109
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0070
# HospCt                                                                                               0.0398
# Hispanic Population                                                                                  -0.0230
# Black Population                                                                                     0.0148
# *** Outbreak Month Temp AVG / F                                                                          -0.0777
#
#
# max var:  Outbreak Month Temp AVG / F
#
#
#
#
# Iteration 3
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F
# score: 0.08307912719831068
# 2wk Prior Mobility                                                                                   0.0873
# *** 2wk Onset Mobility                                                                                   -0.1484
# 2wk Post Mobility                                                                                    0.0674
# inter_movement                                                                                       -0.0054
# out_movement                                                                                         0.0925
# baseline m50 mobility                                                                                -0.0042
# Rural-urban_Continuum Code_2013                                                                      0.0322
# Percent of adults with less than a high school diploma 2014-18                                       0.0141
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0474
# Unemployment_rate_2018                                                                               0.0781
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0661
# Total households!!Average household size                                                             0.0080
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0388
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0148
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0011
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0231
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0035
# HospCt                                                                                               0.0431
# Hispanic Population                                                                                  -0.0349
# Black Population                                                                                     -0.0022
#
#
# max var:  2wk Onset Mobility
#
#
#
#
# Iteration 4
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility
# score: 0.07618627755049279
# 2wk Prior Mobility                                                                                   0.0307
# 2wk Post Mobility                                                                                    -0.0092
# inter_movement                                                                                       0.0122
# *** out_movement                                                                                         0.0965
# baseline m50 mobility                                                                                -0.0179
# Rural-urban_Continuum Code_2013                                                                      0.0256
# Percent of adults with less than a high school diploma 2014-18                                       0.0090
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0520
# Unemployment_rate_2018                                                                               0.0792
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0769
# Total households!!Average household size                                                             0.0080
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0390
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0136
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0003
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0261
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0141
# HospCt                                                                                               0.0407
# Hispanic Population                                                                                  -0.0399
# Black Population                                                                                     -0.0067
#
#
# max var:  out_movement
#
#
#
#
# Iteration 5
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility out_movement
# score: 0.04940040608751628
# 2wk Prior Mobility                                                                                   0.0279
# 2wk Post Mobility                                                                                    -0.0245
# inter_movement                                                                                       -0.0293
# baseline m50 mobility                                                                                0.0025
# Rural-urban_Continuum Code_2013                                                                      0.0152
# Percent of adults with less than a high school diploma 2014-18                                       0.0273
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0518
# *** Unemployment_rate_2018                                                                               0.0667
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0592
# Total households!!Average household size                                                             0.0014
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0431
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0111
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    0.0012
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0310
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0070
# HospCt                                                                                               0.0453
# Hispanic Population                                                                                  -0.0450
# Black Population                                                                                     0.0009
#
#
# max var:  Unemployment_rate_2018
#
#
#
#
# Iteration 6
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility out_movement Unemployment_rate_2018
# score: 0.030373904031672283
# 2wk Prior Mobility                                                                                   0.0174
# 2wk Post Mobility                                                                                    -0.0228
# inter_movement                                                                                       -0.0001
# baseline m50 mobility                                                                                0.0150
# Rural-urban_Continuum Code_2013                                                                      0.0206
# Percent of adults with less than a high school diploma 2014-18                                       0.0069
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0447
# *** Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0496
# Total households!!Average household size                                                             0.0003
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0392
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0103
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    0.0035
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0140
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0112
# HospCt                                                                                               0.0399
# Hispanic Population                                                                                  -0.0334
# Black Population                                                                                     0.0044
#
#
# max var:  Med_HH_Income_Percent_of_State_Total_2018
#
#
#
#
# Iteration 7
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility out_movement Unemployment_rate_2018 Med_HH_Income_Percent_of_State_Total_2018
# score: 0.026809582760613515
# 2wk Prior Mobility                                                                                   0.0113
# 2wk Post Mobility                                                                                    -0.0188
# inter_movement                                                                                       -0.0006
# baseline m50 mobility                                                                                -0.0057
# Rural-urban_Continuum Code_2013                                                                      0.0217
# Percent of adults with less than a high school diploma 2014-18                                       0.0118
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0138
# Total households!!Average household size                                                             -0.0134
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0378
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0112
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0004
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0210
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0037
# *** HospCt                                                                                               0.0380
# Hispanic Population                                                                                  -0.0291
# Black Population                                                                                     0.0068
#
#
# max var:  HospCt
#
#
#
#
# Iteration 8
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility out_movement Unemployment_rate_2018 Med_HH_Income_Percent_of_State_Total_2018 HospCt
# score: 0.01913394997401685
# 2wk Prior Mobility                                                                                   0.0288
# 2wk Post Mobility                                                                                    -0.0115
# inter_movement                                                                                       -0.0220
# baseline m50 mobility                                                                                -0.0082
# Rural-urban_Continuum Code_2013                                                                      0.0149
# Percent of adults with less than a high school diploma 2014-18                                       -0.0262
# Percent of adults with a bachelor's degree or higher 2014-18                                         -0.0100
# Total households!!Average household size                                                             0.0003
# *** SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0401
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0216
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0243
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0292
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0059
# Hispanic Population                                                                                  0.0041
# Black Population                                                                                     0.0192
#
#
# max var:  SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool
#
#
#
#
# Iteration 9
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility out_movement Unemployment_rate_2018 Med_HH_Income_Percent_of_State_Total_2018 HospCt SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool
# score: 0.006930624189173895
# *** 2wk Prior Mobility                                                                                   0.0346
# 2wk Post Mobility                                                                                    -0.0084
# inter_movement                                                                                       -0.0268
# baseline m50 mobility                                                                                -0.0036
# Rural-urban_Continuum Code_2013                                                                      0.0124
# Percent of adults with less than a high school diploma 2014-18                                       -0.0173
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0035
# Total households!!Average household size                                                             0.0032
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0126
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0088
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0251
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0191
# Hispanic Population                                                                                  0.0027
# Black Population                                                                                     0.0018
#
#
# max var:  2wk Prior Mobility
#
#
#
#
# Iteration 10
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility out_movement Unemployment_rate_2018 Med_HH_Income_Percent_of_State_Total_2018 HospCt SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool 2wk Prior Mobility
# score: 0.0017705820668707517
# 2wk Post Mobility                                                                                    0.0007
# inter_movement                                                                                       0.0022
# baseline m50 mobility                                                                                0.0028
# Rural-urban_Continuum Code_2013                                                                      0.0040
# Percent of adults with less than a high school diploma 2014-18                                       0.0081
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0047
# Total households!!Average household size                                                             -0.0077
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0125
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0058
# *** SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0178
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0090
# Hispanic Population                                                                                  -0.0037
# Black Population                                                                                     -0.0009
#
#
# max var:  SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)
#
#
#
#
# Iteration 11
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility out_movement Unemployment_rate_2018 Med_HH_Income_Percent_of_State_Total_2018 HospCt SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool 2wk Prior Mobility SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)
# score: 0.001300070828271216
# 2wk Post Mobility                                                                                    0.0001
# inter_movement                                                                                       -0.0029
# baseline m50 mobility                                                                                0.0043
# Rural-urban_Continuum Code_2013                                                                      0.0035
# Percent of adults with less than a high school diploma 2014-18                                       -0.0034
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0023
# *** Total households!!Average household size                                                             -0.0248
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0095
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    0.0173
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0006
# Hispanic Population                                                                                  0.0156
# Black Population                                                                                     0.0010
#
#
# max var:  Total households!!Average household size
#
#
#
#
# Iteration 12
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility out_movement Unemployment_rate_2018 Med_HH_Income_Percent_of_State_Total_2018 HospCt SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool 2wk Prior Mobility SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12) Total households!!Average household size
# score: 0.0005313147656191841
# 2wk Post Mobility                                                                                    0.0004
# inter_movement                                                                                       -0.0001
# baseline m50 mobility                                                                                -0.0003
# Rural-urban_Continuum Code_2013                                                                      0.0006
# Percent of adults with less than a high school diploma 2014-18                                       0.0031
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0011
# *** SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0104
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    0.0070
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0025
# Hispanic Population                                                                                  -0.0045
# Black Population                                                                                     -0.0013
#
#
# max var:  SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten
#
#
#
#
# Iteration 13
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility out_movement Unemployment_rate_2018 Med_HH_Income_Percent_of_State_Total_2018 HospCt SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool 2wk Prior Mobility SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12) Total households!!Average household size SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten
#
#
#
#
# Density per square mile of land area - Population                                                    & 0.9277 \\hline
# Total_age65plus                                                                                      & 0.1739 \\hline
# Outbreak Month Temp AVG / F                                                                          & -0.0777 \\hline
# 2wk Onset Mobility                                                                                   & -0.1484 \\hline
# out_movement                                                                                         & 0.0965 \\hline
# Unemployment_rate_2018                                                                               & 0.0667 \\hline
# Med_HH_Income_Percent_of_State_Total_2018                                                            & -0.0496 \\hline
# HospCt                                                                                               & 0.0380 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          & 0.0401 \\hline
# 2wk Prior Mobility                                                                                   & 0.0346 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         & 0.0178 \\hline
# Total households!!Average household size                                                             & -0.0248 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      & -0.0104 \\hline

# %% [raw]
# Covid-19 disproportionately affecting Black/Hispanic folks does not necessarily imply that higher black/Hispanic pop percent leads to more deaths
