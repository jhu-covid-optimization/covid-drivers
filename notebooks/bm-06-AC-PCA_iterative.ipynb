# %% [raw]
# Beatriz Medeiros
# Notebook for AC-PCA on independent and dependent variables separately

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.linear_model as lm
from collections import defaultdict
import sys; sys.path.append('../')
from src.data_analysis.tools import ac_pca

# %% [markdown]
# ## Get Preprocessed data

# %%
combined_data = pd.read_csv('../data/intermediates/pre_acpca1.csv')
combined_data.set_index('FIPS', inplace=True)
print(combined_data.shape)
ind_vars = list(combined_data.columns)
total_vars = len(ind_vars)
combined_data.head()
# Out:
# (489, 22)
#       inter_movement  out_movement  baseline m50 mobility  \
# FIPS
# 1003        0.519349      0.244188               0.610171
# 1051        0.452205      0.745075               0.840246
# 1055        0.677227      0.378689               0.449395
# 1073        0.775948      0.190299               0.483877
# 1081        0.572121      0.464994               0.307942
#
#       Density per square mile of land area - Population  \
# FIPS
# 1003                                           0.001558
# 1051                                           0.001753
# 1055                                           0.002718
# 1073                                           0.008438
# 1081                                           0.003231
#
#       Rural-urban_Continuum Code_2013  \
# FIPS
# 1003                              0.4
# 1051                              0.2
# 1055                              0.4
# 1073                              0.0
# 1081                              0.4
#
#       Percent of adults with less than a high school diploma 2014-18  \
# FIPS
# 1003                                           0.229851
# 1051                                           0.346269
# 1055                                           0.402985
# 1073                                           0.247761
# 1081                                           0.223881
#
#       Percent of adults with a bachelor's degree or higher 2014-18  \
# FIPS
# 1003                                           0.312698
# 1051                                           0.204762
# 1055                                           0.096825
# 1073                                           0.330159
# 1081                                           0.357143
#
#       Unemployment_rate_2018  Med_HH_Income_Percent_of_State_Total_2018  \
# FIPS
# 1003                0.104938                                   0.373373
# 1051                0.092593                                   0.405917
# 1055                0.135802                                   0.222485
# 1073                0.111111                                   0.342604
# 1081                0.104938                                   0.270414
#
#       Total_age65plus  ...  \
# FIPS                   ...
# 1003         0.255108  ...
# 1051         0.148810  ...
# 1055         0.226393  ...
# 1073         0.163138  ...
# 1081         0.083435  ...
#
#       SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten  \
# FIPS
# 1003                                           0.129585
# 1051                                           0.130406
# 1055                                           0.358494
# 1073                                           0.386817
# 1081                                           0.144048
#
#       SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)  \
# FIPS
# 1003                                           0.627997
# 1051                                           0.487643
# 1055                                           0.567540
# 1073                                           0.576102
# 1081                                           0.571650
#
#       SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)  \
# FIPS
# 1003                                           0.462848
# 1051                                           0.645915
# 1055                                           0.360599
# 1073                                           0.416900
# 1081                                           0.442769
#
#       SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school  \
# FIPS
# 1003                                           0.038455
# 1051                                           0.113909
# 1055                                           0.075155
# 1073                                           0.172229
# 1081                                           0.609583
#
#         HospCt  Hispanic Population  Black Population  \
# FIPS
# 1003  0.170836             0.038549          0.116681
# 1051  0.338853             0.021248          0.290098
# 1055  0.261462             0.031866          0.210358
# 1073  0.169115             0.031499          0.594907
# 1081  0.050141             0.029159          0.312716
#
#       Outbreak Month Temp AVG / F    Deaths  normalized_deaths
# FIPS
# 1003                     0.952015  0.000789           0.010689
# 1051                     0.923225  0.000789           0.032762
# 1055                     0.689060  0.000986           0.028791
# 1073                     0.694818  0.005521           0.013511
# 1081                     0.704415  0.003943           0.046459
#
# [5 rows x 22 columns]

# %%
ind_vars
# Out:
# ['inter_movement',
#  'out_movement',
#  'baseline m50 mobility',
#  'Density per square mile of land area - Population',
#  'Rural-urban_Continuum Code_2013',
#  'Percent of adults with less than a high school diploma 2014-18',
#  "Percent of adults with a bachelor's degree or higher 2014-18",
#  'Unemployment_rate_2018',
#  'Med_HH_Income_Percent_of_State_Total_2018',
#  'Total_age65plus',
#  'Total households!!Average household size',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school',
#  'HospCt',
#  'Hispanic Population',
#  'Black Population',
#  'Outbreak Month Temp AVG / F',
#  'Deaths',
#  'normalized_deaths']

# %% [markdown]
# ## Run AC-PCA

# %%
def run_acpca(combined_data, confounders):
    ind_vars = list(combined_data.drop(columns=confounders).columns)
    X = combined_data.drop(columns=['Deaths', 'normalized_deaths'], inplace=False)
    X = X.drop(columns=confounders, inplace=False).to_numpy() # 'Density per square mile of land area - Population',
#     print(X.shape)
    X_rows, X_cols = X.shape
    column_names = ['PC' + str(i) for i in range(1, X_cols + 1)]
    if len(confounders) > 0: 
        Y = combined_data.filter(confounders).to_numpy()
    else: 
        Y = np.zeros((X_rows))
    if len(Y.shape) < 2: 
        Y = Y.reshape(len(Y), 1)
    acpca_data, PCs, eigens = ac_pca(X, Y)
    acpca_data = acpca_data.to_numpy()
    PCs = PCs.to_numpy()
    eigens = eigens.to_numpy()
    return acpca_data, PCs, eigens, column_names, ind_vars

# %% [markdown]
# ## Run linear regression on all PCs and get coefficients

# %%
def linreg_coeffs(combined_data, acpca_data, eigens):   
    _, total_pcs = eigens.shape
    pos_pcs = []
    for pc in range(total_pcs): 
        eig = eigens[0,pc]
        if eig > 0: 
            pos_pcs.append(pc)
    if len(pos_pcs) == 0: 
        return 0, 0, pos_pcs
    X = acpca_data[:,pos_pcs]
    Y = combined_data['normalized_deaths']
    reg = lm.LinearRegression().fit(X,Y)
    final_score = reg.score(X,Y)
    coeffs = {}
    for i in range(len(pos_pcs)): 
        coeffs[pos_pcs[i]] = reg.coef_[i]
    return final_score, coeffs, pos_pcs

# %% [markdown]
# ## Calculate individual weight of each variable

# %%
def calc_weights(coeffs, pos_pcs, ind_vars):
    weights = {}
    r,c = PCs.shape
    for pc in pos_pcs: 
        eig = eigens[0, pc]
        PC_dict = {}
        # PC9 = [-0.190896056547888, 0.468236937317933,-0.228567222005448,0.408002822993487,0.0535105125245226,0.407238079363182,0.181820228133276,0.366604933989350,0.435246581102968]
        for i in range(r): 
        #     print('{0:<80} \t {1:>0.3f}'.format(combined_data.columns.values[i+2], PC9[i]))
            loading = PCs[i,pc] # weight of variable in component
            variable = ind_vars[i] # variable name in column headers 
            PC_dict[variable] = loading
            coef = coeffs[pc] # coefficient corresponding to PC
            if variable not in weights:
                weights[variable] = 0
            weights[variable] += coef * loading
    return weights

# %% [markdown]
# ## Print results and identify strongest variable

# %%
def results(weights, final_score, mobility_features):
    print('score:', final_score)
    max_weight_mag = np.max(np.abs(np.array(list(weights.values()))))
    max_weight = 0
    max_var = None
    max_mobility_weight = 0
    max_mobility_var = None
    for var, weight in weights.items():
        if var in mobility_features and weight > max_mobility_weight:
            max_mobility_weight = weight
            max_mobility_var = var
    #     print('{0:<100} & {1:>0.4f} \\\\ \hline'.format(var.replace('_', '\\_'), weight))
        if abs(weight) == max_weight_mag: 
            max_weight = weight
            max_var = var
            print('*** {0:<100} {1:>0.4f}'.format(var, weight))
        else:
            print('{0:<100} {1:>0.4f}'.format(var, weight))
    print('\n\nmax var: ', max_var)
    return max_var, max_weight, max_mobility_var, max_mobility_weight

# %%
mobility_features = ['inter_movement', 'out_movement', 'baseline m50 mobility']
confounders = {} 
it = 0 
while len(confounders) < total_vars - 1:
    print('Iteration', it)
    print('confounders:', *confounders.keys())
    it += 1
    acpca_data, PCs, eigens, column_names, ind_vars = run_acpca(combined_data, confounders)
    final_score, coeffs, pos_pcs = linreg_coeffs(combined_data, acpca_data, eigens)
    if len(pos_pcs) == 0: 
        print('\n\n\n')
        break 
    weights = calc_weights(coeffs, pos_pcs, ind_vars)
    max_var, max_weight, max_mobility_var, max_mobility_weight = results(weights, final_score, mobility_features)
    confounders[max_var] = max_weight
    print('\n\n\n')
for var, weight in confounders.items():
    print('{0:<100} & {1:>0.4f} \\\\hline'.format(var, weight))
# Out:
# Iteration 0
# confounders:
# score: 0.6466345945511351
# inter_movement                                                                                       0.0319
# out_movement                                                                                         0.0910
# baseline m50 mobility                                                                                0.0293
# *** Density per square mile of land area - Population                                                    0.9441
# Rural-urban_Continuum Code_2013                                                                      0.0489
# Percent of adults with less than a high school diploma 2014-18                                       0.0306
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0095
# Unemployment_rate_2018                                                                               0.0492
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0298
# Total_age65plus                                                                                      0.1717
# Total households!!Average household size                                                             0.0280
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0430
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0059
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    0.0515
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0160
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0368
# HospCt                                                                                               0.0343
# Hispanic Population                                                                                  -0.0226
# Black Population                                                                                     0.0230
# Outbreak Month Temp AVG / F                                                                          -0.0858
#
#
# max var:  Density per square mile of land area - Population
#
#
#
#
# Iteration 1
# confounders: Density per square mile of land area - Population
# score: 0.14064823106081326
# inter_movement                                                                                       0.0339
# out_movement                                                                                         0.0969
# baseline m50 mobility                                                                                0.0163
# Rural-urban_Continuum Code_2013                                                                      0.0401
# Percent of adults with less than a high school diploma 2014-18                                       0.0427
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0266
# Unemployment_rate_2018                                                                               0.0483
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0247
# *** Total_age65plus                                                                                      0.1569
# Total households!!Average household size                                                             0.0222
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0429
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0121
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    0.0366
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0040
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0284
# HospCt                                                                                               0.0334
# Hispanic Population                                                                                  -0.0166
# Black Population                                                                                     0.0293
# Outbreak Month Temp AVG / F                                                                          -0.0932
#
#
# max var:  Total_age65plus
#
#
#
#
# Iteration 2
# confounders: Density per square mile of land area - Population Total_age65plus
# score: 0.12408911140788037
# inter_movement                                                                                       0.0238
# out_movement                                                                                         0.0784
# baseline m50 mobility                                                                                0.0225
# Rural-urban_Continuum Code_2013                                                                      0.0496
# Percent of adults with less than a high school diploma 2014-18                                       0.0160
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0133
# Unemployment_rate_2018                                                                               0.0639
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0351
# Total households!!Average household size                                                             0.0341
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0346
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0239
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0222
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0087
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0121
# HospCt                                                                                               0.0372
# Hispanic Population                                                                                  -0.0232
# Black Population                                                                                     0.0159
# *** Outbreak Month Temp AVG / F                                                                          -0.0789
#
#
# max var:  Outbreak Month Temp AVG / F
#
#
#
#
# Iteration 3
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F
# score: 0.07478428122902159
# inter_movement                                                                                       0.0299
# *** out_movement                                                                                         0.1015
# baseline m50 mobility                                                                                -0.0178
# Rural-urban_Continuum Code_2013                                                                      0.0266
# Percent of adults with less than a high school diploma 2014-18                                       0.0210
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0513
# Unemployment_rate_2018                                                                               0.0781
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0708
# Total households!!Average household size                                                             0.0055
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0380
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0160
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0015
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0216
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0198
# HospCt                                                                                               0.0388
# Hispanic Population                                                                                  -0.0387
# Black Population                                                                                     -0.0016
#
#
# max var:  out_movement
#
#
#
#
# Iteration 4
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F out_movement
# score: 0.04746386870459707
# inter_movement                                                                                       -0.0212
# baseline m50 mobility                                                                                0.0023
# Rural-urban_Continuum Code_2013                                                                      0.0157
# Percent of adults with less than a high school diploma 2014-18                                       0.0507
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0549
# *** Unemployment_rate_2018                                                                               0.0652
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0505
# Total households!!Average household size                                                             -0.0078
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0431
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0135
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0006
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0291
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0098
# HospCt                                                                                               0.0445
# Hispanic Population                                                                                  -0.0459
# Black Population                                                                                     0.0043
#
#
# max var:  Unemployment_rate_2018
#
#
#
#
# Iteration 5
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F out_movement Unemployment_rate_2018
# score: 0.028422028751641237
# inter_movement                                                                                       0.0017
# baseline m50 mobility                                                                                0.0165
# Rural-urban_Continuum Code_2013                                                                      0.0227
# Percent of adults with less than a high school diploma 2014-18                                       0.0238
# *** Percent of adults with a bachelor's degree or higher 2014-18                                         0.0488
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0422
# Total households!!Average household size                                                             -0.0060
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0388
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0127
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    0.0014
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0131
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0092
# HospCt                                                                                               0.0393
# Hispanic Population                                                                                  -0.0343
# Black Population                                                                                     0.0058
#
#
# max var:  Percent of adults with a bachelor's degree or higher 2014-18
#
#
#
#
# Iteration 6
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F out_movement Unemployment_rate_2018 Percent of adults with a bachelor's degree or higher 2014-18
# score: 0.02374530571832112
# inter_movement                                                                                       -0.0046
# baseline m50 mobility                                                                                -0.0047
# Rural-urban_Continuum Code_2013                                                                      0.0123
# Percent of adults with less than a high school diploma 2014-18                                       0.0030
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0021
# Total households!!Average household size                                                             -0.0084
# *** SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0465
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0106
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0142
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0131
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0021
# HospCt                                                                                               0.0391
# Hispanic Population                                                                                  -0.0170
# Black Population                                                                                     0.0164
#
#
# max var:  SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool
#
#
#
#
# Iteration 7
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F out_movement Unemployment_rate_2018 Percent of adults with a bachelor's degree or higher 2014-18 SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool
# score: 0.013862673092344457
# inter_movement                                                                                       -0.0105
# baseline m50 mobility                                                                                -0.0112
# Rural-urban_Continuum Code_2013                                                                      0.0077
# Percent of adults with less than a high school diploma 2014-18                                       0.0018
# Med_HH_Income_Percent_of_State_Total_2018                                                            0.0069
# Total households!!Average household size                                                             -0.0145
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0070
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0005
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0161
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0214
# *** HospCt                                                                                               0.0372
# Hispanic Population                                                                                  -0.0120
# Black Population                                                                                     0.0169
#
#
# max var:  HospCt
#
#
#
#
# Iteration 8
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F out_movement Unemployment_rate_2018 Percent of adults with a bachelor's degree or higher 2014-18 SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool HospCt
# score: 0.006687335085488022
# inter_movement                                                                                       -0.0032
# baseline m50 mobility                                                                                -0.0015
# Rural-urban_Continuum Code_2013                                                                      -0.0062
# Percent of adults with less than a high school diploma 2014-18                                       -0.0016
# *** Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0161
# Total households!!Average household size                                                             0.0001
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0140
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0043
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0072
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0124
# Hispanic Population                                                                                  -0.0118
# Black Population                                                                                     0.0158
#
#
# max var:  Med_HH_Income_Percent_of_State_Total_2018
#
#
#
#
# Iteration 9
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F out_movement Unemployment_rate_2018 Percent of adults with a bachelor's degree or higher 2014-18 SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool HospCt Med_HH_Income_Percent_of_State_Total_2018
# score: 0.0009835012835313073
# inter_movement                                                                                       -0.0012
# baseline m50 mobility                                                                                -0.0049
# Rural-urban_Continuum Code_2013                                                                      -0.0015
# Percent of adults with less than a high school diploma 2014-18                                       0.0032
# *** Total households!!Average household size                                                             0.0186
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0055
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    0.0057
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         -0.0120
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0003
# Hispanic Population                                                                                  -0.0149
# Black Population                                                                                     -0.0003
#
#
# max var:  Total households!!Average household size
#
#
#
#
# Iteration 10
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F out_movement Unemployment_rate_2018 Percent of adults with a bachelor's degree or higher 2014-18 SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool HospCt Med_HH_Income_Percent_of_State_Total_2018 Total households!!Average household size
# score: 0.0003867281594165384
# inter_movement                                                                                       -0.0034
# baseline m50 mobility                                                                                -0.0009
# Rural-urban_Continuum Code_2013                                                                      0.0010
# Percent of adults with less than a high school diploma 2014-18                                       -0.0046
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      0.0004
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    0.0093
# *** SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         -0.0100
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0035
# Hispanic Population                                                                                  0.0044
# Black Population                                                                                     0.0013
#
#
# max var:  SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)
#
#
#
#
# Iteration 11
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F out_movement Unemployment_rate_2018 Percent of adults with a bachelor's degree or higher 2014-18 SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool HospCt Med_HH_Income_Percent_of_State_Total_2018 Total households!!Average household size SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)
# score: 1.1953865192593227e-05
# inter_movement                                                                                       -0.0001
# baseline m50 mobility                                                                                -0.0000
# Rural-urban_Continuum Code_2013                                                                      0.0002
# Percent of adults with less than a high school diploma 2014-18                                       0.0000
# *** SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0016
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    0.0011
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0004
# Hispanic Population                                                                                  -0.0004
# Black Population                                                                                     -0.0001
#
#
# max var:  SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten
#
#
#
#
# Iteration 12
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F out_movement Unemployment_rate_2018 Percent of adults with a bachelor's degree or higher 2014-18 SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool HospCt Med_HH_Income_Percent_of_State_Total_2018 Total households!!Average household size SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12) SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten
#
#
#
#
# Density per square mile of land area - Population                                                    & 0.9441 \\hline
# Total_age65plus                                                                                      & 0.1569 \\hline
# Outbreak Month Temp AVG / F                                                                          & -0.0789 \\hline
# out_movement                                                                                         & 0.1015 \\hline
# Unemployment_rate_2018                                                                               & 0.0652 \\hline
# Percent of adults with a bachelor's degree or higher 2014-18                                         & 0.0488 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          & 0.0465 \\hline
# HospCt                                                                                               & 0.0372 \\hline
# Med_HH_Income_Percent_of_State_Total_2018                                                            & -0.0161 \\hline
# Total households!!Average household size                                                             & 0.0186 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         & -0.0100 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      & -0.0016 \\hline

# %% [raw]
# Covid-19 disproportionately affecting Black/Hispanic folks does not necessarily imply that higher black/Hispanic pop percent leads to more deaths
