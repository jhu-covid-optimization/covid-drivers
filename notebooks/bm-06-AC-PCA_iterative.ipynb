# %% [raw]
# Beatriz Medeiros
# Notebook for AC-PCA on independent and dependent variables separately

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.linear_model as lm
from collections import defaultdict
import sys; sys.path.append('../')
from src.data_analysis.tools import ac_pca

# %% [markdown]
# ## Get Preprocessed data

# %%
combined_data = pd.read_csv('../data/intermediates/pre_acpca1.csv')
combined_data.set_index('FIPS', inplace=True)
print(combined_data.shape)
ind_vars = list(combined_data.columns)
total_vars = len(ind_vars)
combined_data.head()
# Out:
# (450, 28)
#       Unnamed: 0  2wk Prior Mobility  2wk Onset Mobility  2wk Post Mobility  \
# FIPS
# 1003           0            0.459962            0.738688           0.824197
# 1051           1            0.521206            0.785409           0.844992
# 1073           2            0.581889            0.834773           0.879697
# 1081           3            0.301939            0.575735           0.703762
# 1089           4            0.492726            0.741843           0.824973
#
#       inter_movement  out_movement  baseline m50 mobility  \
# FIPS
# 1003        0.519349      0.327736               0.663421
# 1051        0.452205      1.000000               0.913574
# 1073        0.775948      0.255409               0.526105
# 1081        0.572121      0.624091               0.334816
# 1089        0.686220      0.197095               0.553652
#
#       Density per square mile of land area - Population  \
# FIPS
# 1003                                           0.001558
# 1051                                           0.001753
# 1073                                           0.008438
# 1081                                           0.003231
# 1089                                           0.005921
#
#       Rural-urban_Continuum Code_2013  \
# FIPS
# 1003                              0.4
# 1051                              0.2
# 1073                              0.0
# 1081                              0.4
# 1089                              0.2
#
#       Percent of adults with less than a high school diploma 2014-18  ...  \
# FIPS                                                                  ...
# 1003                                           0.229851               ...
# 1051                                           0.346269               ...
# 1073                                           0.247761               ...
# 1081                                           0.223881               ...
# 1089                                           0.205970               ...
#
#       SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)  \
# FIPS
# 1003                                           0.500894
# 1051                                           0.710722
# 1073                                           0.448229
# 1081                                           0.477880
# 1089                                           0.524713
#
#       SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school  \
# FIPS
# 1003                                           0.023750
# 1051                                           0.104400
# 1073                                           0.166735
# 1081                                           0.634204
# 1089                                           0.251270
#
#         HospCt  Longterm Beds  Hispanic Population  Black Population  \
# FIPS
# 1003  0.207274       0.000000             0.038549          0.116048
# 1051  0.367907       0.000000             0.021248          0.289589
# 1073  0.205628       0.092831             0.031499          0.594616
# 1081  0.091883       0.000000             0.029159          0.312223
# 1089  0.123296       0.000000             0.043017          0.337374
#
#       Outbreak Month Temp AVG / F  Time from outbreak to intervention  \
# FIPS
# 1003                     0.754826                            0.959795
# 1051                     0.928571                            0.947819
# 1073                     0.698842                            0.976048
# 1081                     0.708494                            0.974337
# 1089                     0.666023                            0.969204
#
#         Deaths  normalized_deaths
# FIPS
# 1003  0.000591           0.006585
# 1051  0.000788           0.025222
# 1073  0.005518           0.012855
# 1081  0.003745           0.040884
# 1089  0.000197           0.001246
#
# [5 rows x 28 columns]

# %%
ind_vars
# Out:
# ['Unnamed: 0',
#  '2wk Prior Mobility',
#  '2wk Onset Mobility',
#  '2wk Post Mobility',
#  'inter_movement',
#  'out_movement',
#  'baseline m50 mobility',
#  'Density per square mile of land area - Population',
#  'Rural-urban_Continuum Code_2013',
#  'Percent of adults with less than a high school diploma 2014-18',
#  "Percent of adults with a bachelor's degree or higher 2014-18",
#  'Unemployment_rate_2018',
#  'Med_HH_Income_Percent_of_State_Total_2018',
#  'Total_age65plus',
#  'Total households!!Average household size',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)',
#  'SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school',
#  'HospCt',
#  'Longterm Beds',
#  'Hispanic Population',
#  'Black Population',
#  'Outbreak Month Temp AVG / F',
#  'Time from outbreak to intervention',
#  'Deaths',
#  'normalized_deaths']

# %% [markdown]
# ## Run AC-PCA

# %%
def run_acpca(combined_data, confounders):
    ind_vars = list(combined_data.drop(columns=confounders).columns)
    X = combined_data.drop(columns=['Deaths', 'normalized_deaths'], inplace=False)
    X = X.drop(columns=confounders, inplace=False).to_numpy() # 'Density per square mile of land area - Population',
#     print(X.shape)
    X_rows, X_cols = X.shape
    column_names = ['PC' + str(i) for i in range(1, X_cols + 1)]
    if len(confounders) > 0: 
        Y = combined_data.filter(confounders).to_numpy()
    else: 
        Y = np.zeros((X_rows))
    if len(Y.shape) < 2: 
        Y = Y.reshape(len(Y), 1)
    acpca_data, PCs, eigens = ac_pca(X, Y)
    acpca_data = acpca_data.to_numpy()
    PCs = PCs.to_numpy()
    eigens = eigens.to_numpy()
    return acpca_data, PCs, eigens, column_names, ind_vars

# %% [markdown]
# ## Run linear regression on all PCs and get coefficients

# %%
def linreg_coeffs(combined_data, acpca_data, eigens):   
    _, total_pcs = eigens.shape
    pos_pcs = []
    for pc in range(total_pcs): 
        eig = eigens[0,pc]
        if eig > 0: 
            pos_pcs.append(pc)
    if len(pos_pcs) == 0: 
        return 0, 0, pos_pcs
    X = acpca_data[:,pos_pcs]
    Y = combined_data['normalized_deaths']
    reg = lm.LinearRegression().fit(X,Y)
    final_score = reg.score(X,Y)
    coeffs = {}
    for i in range(len(pos_pcs)): 
        coeffs[pos_pcs[i]] = reg.coef_[i]
    return final_score, coeffs, pos_pcs

# %% [markdown]
# ## Calculate individual weight of each variable

# %%
def calc_weights(coeffs, pos_pcs, ind_vars):
    weights = {}
    r,c = PCs.shape
    for pc in pos_pcs: 
        eig = eigens[0, pc]
        PC_dict = {}
        # PC9 = [-0.190896056547888, 0.468236937317933,-0.228567222005448,0.408002822993487,0.0535105125245226,0.407238079363182,0.181820228133276,0.366604933989350,0.435246581102968]
        for i in range(r): 
        #     print('{0:<80} \t {1:>0.3f}'.format(combined_data.columns.values[i+2], PC9[i]))
            loading = PCs[i,pc] # weight of variable in component
            variable = ind_vars[i] # variable name in column headers 
            PC_dict[variable] = loading
            coef = coeffs[pc] # coefficient corresponding to PC
            if variable not in weights:
                weights[variable] = 0
            weights[variable] += coef * loading
    return weights

# %% [markdown]
# ## Print results and identify strongest variable

# %%
def results(weights, final_score, mobility_features):
    print('score:', final_score)
    max_weight_mag = np.max(np.abs(np.array(list(weights.values()))))
    max_weight = 0
    max_var = None
    max_mobility_weight = 0
    max_mobility_var = None
    for var, weight in weights.items():
        if var in mobility_features and weight > max_mobility_weight:
            max_mobility_weight = weight
            max_mobility_var = var
    #     print('{0:<100} & {1:>0.4f} \\\\ \hline'.format(var.replace('_', '\\_'), weight))
        if abs(weight) == max_weight_mag: 
            max_weight = weight
            max_var = var
            print('*** {0:<100} {1:>0.4f}'.format(var, weight))
        else:
            print('{0:<100} {1:>0.4f}'.format(var, weight))
    print('\n\nmax var: ', max_var)
    return max_var, max_weight, max_mobility_var, max_mobility_weight

# %%
mobility_features = ['inter_movement', 'out_movement', 'baseline m50 mobility']
confounders = {} 
it = 0 
while len(confounders) < total_vars - 1:
    print('Iteration', it)
    print('confounders:', *confounders.keys())
    it += 1
    acpca_data, PCs, eigens, column_names, ind_vars = run_acpca(combined_data, confounders)
    final_score, coeffs, pos_pcs = linreg_coeffs(combined_data, acpca_data, eigens)
    if len(pos_pcs) == 0: 
        print('\n\n\n')
        break 
    weights = calc_weights(coeffs, pos_pcs, ind_vars)
    max_var, max_weight, max_mobility_var, max_mobility_weight = results(weights, final_score, mobility_features)
    confounders[max_var] = max_weight
    print('\n\n\n')
for var, weight in confounders.items():
    print('{0:<100} & {1:>0.4f} \\\\hline'.format(var, weight))
# Out:
# Iteration 0
# confounders:
# score: 0.7072951474258622
# Unnamed: 0                                                                                           0.0000
# 2wk Prior Mobility                                                                                   0.0197
# 2wk Onset Mobility                                                                                   0.0125
# 2wk Post Mobility                                                                                    -0.0229
# inter_movement                                                                                       0.0240
# out_movement                                                                                         0.0646
# baseline m50 mobility                                                                                0.0410
# *** Density per square mile of land area - Population                                                    0.9555
# Rural-urban_Continuum Code_2013                                                                      0.0519
# Percent of adults with less than a high school diploma 2014-18                                       0.0052
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0203
# Unemployment_rate_2018                                                                               0.0405
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0437
# Total_age65plus                                                                                      0.2165
# Total households!!Average household size                                                             0.0373
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0424
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      0.0088
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    0.0535
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0355
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0544
# HospCt                                                                                               0.0318
# Longterm Beds                                                                                        -0.0099
# Hispanic Population                                                                                  -0.0089
# Black Population                                                                                     0.0359
# Outbreak Month Temp AVG / F                                                                          -0.0779
# Time from outbreak to intervention                                                                   -0.0180
#
#
# max var:  Density per square mile of land area - Population
#
#
#
#
# Iteration 1
# confounders: Density per square mile of land area - Population
# score: 0.13534582900180614
# Unnamed: 0                                                                                           0.0000
# 2wk Prior Mobility                                                                                   0.0322
# 2wk Onset Mobility                                                                                   0.0199
# 2wk Post Mobility                                                                                    -0.0320
# inter_movement                                                                                       0.0155
# out_movement                                                                                         0.0724
# baseline m50 mobility                                                                                0.0229
# Rural-urban_Continuum Code_2013                                                                      0.0412
# Percent of adults with less than a high school diploma 2014-18                                       0.0256
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0444
# Unemployment_rate_2018                                                                               0.0403
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0379
# *** Total_age65plus                                                                                      0.1959
# Total households!!Average household size                                                             0.0312
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0427
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      0.0007
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    0.0336
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0217
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0458
# HospCt                                                                                               0.0330
# Longterm Beds                                                                                        -0.0048
# Hispanic Population                                                                                  -0.0051
# Black Population                                                                                     0.0401
# Outbreak Month Temp AVG / F                                                                          -0.0844
# Time from outbreak to intervention                                                                   -0.0165
#
#
# max var:  Total_age65plus
#
#
#
#
# Iteration 2
# confounders: Density per square mile of land area - Population Total_age65plus
# score: 0.10861792652989022
# Unnamed: 0                                                                                           0.0000
# 2wk Prior Mobility                                                                                   0.0353
# 2wk Onset Mobility                                                                                   -0.0311
# 2wk Post Mobility                                                                                    0.0097
# inter_movement                                                                                       0.0128
# out_movement                                                                                         0.0557
# baseline m50 mobility                                                                                0.0297
# Rural-urban_Continuum Code_2013                                                                      0.0576
# Percent of adults with less than a high school diploma 2014-18                                       -0.0105
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0243
# Unemployment_rate_2018                                                                               0.0583
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0477
# Total households!!Average household size                                                             0.0360
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0306
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0139
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0454
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0231
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0145
# HospCt                                                                                               0.0371
# Longterm Beds                                                                                        -0.0083
# Hispanic Population                                                                                  -0.0052
# Black Population                                                                                     0.0236
# *** Outbreak Month Temp AVG / F                                                                          -0.0657
# Time from outbreak to intervention                                                                   -0.0147
#
#
# max var:  Outbreak Month Temp AVG / F
#
#
#
#
# Iteration 3
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F
# score: 0.07182832999469446
# Unnamed: 0                                                                                           0.0000
# 2wk Prior Mobility                                                                                   0.0837
# *** 2wk Onset Mobility                                                                                   -0.0979
# 2wk Post Mobility                                                                                    0.0670
# inter_movement                                                                                       -0.0051
# out_movement                                                                                         0.0659
# baseline m50 mobility                                                                                0.0075
# Rural-urban_Continuum Code_2013                                                                      0.0441
# Percent of adults with less than a high school diploma 2014-18                                       -0.0012
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0488
# Unemployment_rate_2018                                                                               0.0643
# Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0646
# Total households!!Average household size                                                             0.0135
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0346
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0095
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0287
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0318
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0113
# HospCt                                                                                               0.0435
# Longterm Beds                                                                                        -0.0050
# Hispanic Population                                                                                  -0.0128
# Black Population                                                                                     0.0125
# Time from outbreak to intervention                                                                   -0.0086
#
#
# max var:  2wk Onset Mobility
#
#
#
#
# Iteration 4
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility
# score: 0.06823986294458106
# Unnamed: 0                                                                                           0.0000
# 2wk Prior Mobility                                                                                   0.0466
# 2wk Post Mobility                                                                                    -0.0052
# inter_movement                                                                                       -0.0034
# out_movement                                                                                         0.0646
# baseline m50 mobility                                                                                0.0037
# Rural-urban_Continuum Code_2013                                                                      0.0378
# Percent of adults with less than a high school diploma 2014-18                                       -0.0016
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0573
# Unemployment_rate_2018                                                                               0.0633
# *** Med_HH_Income_Percent_of_State_Total_2018                                                            -0.0781
# Total households!!Average household size                                                             0.0165
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0354
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0070
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0281
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0353
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0149
# HospCt                                                                                               0.0441
# Longterm Beds                                                                                        -0.0039
# Hispanic Population                                                                                  -0.0230
# Black Population                                                                                     0.0055
# Time from outbreak to intervention                                                                   -0.0056
#
#
# max var:  Med_HH_Income_Percent_of_State_Total_2018
#
#
#
#
# Iteration 5
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility Med_HH_Income_Percent_of_State_Total_2018
# score: 0.05871150506449385
# Unnamed: 0                                                                                           0.0000
# 2wk Prior Mobility                                                                                   0.0446
# 2wk Post Mobility                                                                                    0.0021
# inter_movement                                                                                       -0.0160
# out_movement                                                                                         0.0549
# baseline m50 mobility                                                                                -0.0149
# Rural-urban_Continuum Code_2013                                                                      0.0342
# Percent of adults with less than a high school diploma 2014-18                                       0.0000
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0129
# *** Unemployment_rate_2018                                                                               0.0741
# Total households!!Average household size                                                             -0.0131
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0340
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0075
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0286
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0416
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0032
# HospCt                                                                                               0.0411
# Longterm Beds                                                                                        0.0003
# Hispanic Population                                                                                  -0.0179
# Black Population                                                                                     0.0059
# Time from outbreak to intervention                                                                   -0.0050
#
#
# max var:  Unemployment_rate_2018
#
#
#
#
# Iteration 6
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility Med_HH_Income_Percent_of_State_Total_2018 Unemployment_rate_2018
# score: 0.04849160930327612
# Unnamed: 0                                                                                           -0.0000
# 2wk Prior Mobility                                                                                   0.0420
# 2wk Post Mobility                                                                                    0.0034
# inter_movement                                                                                       -0.0170
# *** out_movement                                                                                         0.0518
# baseline m50 mobility                                                                                -0.0193
# Rural-urban_Continuum Code_2013                                                                      0.0331
# Percent of adults with less than a high school diploma 2014-18                                       0.0004
# Percent of adults with a bachelor's degree or higher 2014-18                                         -0.0058
# Total households!!Average household size                                                             -0.0252
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0333
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0074
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0267
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0413
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0114
# HospCt                                                                                               0.0383
# Longterm Beds                                                                                        0.0014
# Hispanic Population                                                                                  -0.0106
# Black Population                                                                                     0.0071
# Time from outbreak to intervention                                                                   -0.0061
#
#
# max var:  out_movement
#
#
#
#
# Iteration 7
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility Med_HH_Income_Percent_of_State_Total_2018 Unemployment_rate_2018 out_movement
# score: 0.02906533166703207
# Unnamed: 0                                                                                           0.0000
# 2wk Prior Mobility                                                                                   0.0260
# 2wk Post Mobility                                                                                    -0.0176
# inter_movement                                                                                       -0.0164
# baseline m50 mobility                                                                                -0.0028
# Rural-urban_Continuum Code_2013                                                                      0.0306
# Percent of adults with less than a high school diploma 2014-18                                       0.0024
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0100
# Total households!!Average household size                                                             -0.0055
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0340
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0069
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0284
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0375
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0027
# *** HospCt                                                                                               0.0385
# Longterm Beds                                                                                        0.0016
# Hispanic Population                                                                                  -0.0148
# Black Population                                                                                     0.0131
# Time from outbreak to intervention                                                                   -0.0048
#
#
# max var:  HospCt
#
#
#
#
# Iteration 8
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility Med_HH_Income_Percent_of_State_Total_2018 Unemployment_rate_2018 out_movement HospCt
# score: 0.018812612294530018
# Unnamed: 0                                                                                           0.0000
# 2wk Prior Mobility                                                                                   0.0321
# 2wk Post Mobility                                                                                    -0.0100
# inter_movement                                                                                       -0.0254
# baseline m50 mobility                                                                                -0.0055
# Rural-urban_Continuum Code_2013                                                                      0.0208
# Percent of adults with less than a high school diploma 2014-18                                       -0.0245
# Percent of adults with a bachelor's degree or higher 2014-18                                         -0.0119
# Total households!!Average household size                                                             -0.0010
# *** SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          0.0370
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0082
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0354
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0278
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0023
# Longterm Beds                                                                                        -0.0167
# Hispanic Population                                                                                  0.0126
# Black Population                                                                                     0.0206
# Time from outbreak to intervention                                                                   -0.0015
#
#
# max var:  SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool
#
#
#
#
# Iteration 9
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility Med_HH_Income_Percent_of_State_Total_2018 Unemployment_rate_2018 out_movement HospCt SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool
# score: 0.011517406834664734
# Unnamed: 0                                                                                           0.0000
# *** 2wk Prior Mobility                                                                                   0.0398
# 2wk Post Mobility                                                                                    -0.0088
# inter_movement                                                                                       -0.0272
# baseline m50 mobility                                                                                -0.0024
# Rural-urban_Continuum Code_2013                                                                      0.0177
# Percent of adults with less than a high school diploma 2014-18                                       -0.0175
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0031
# Total households!!Average household size                                                             0.0006
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0037
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0227
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0301
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0089
# Longterm Beds                                                                                        -0.0135
# Hispanic Population                                                                                  0.0095
# Black Population                                                                                     0.0138
# Time from outbreak to intervention                                                                   0.0026
#
#
# max var:  2wk Prior Mobility
#
#
#
#
# Iteration 10
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility Med_HH_Income_Percent_of_State_Total_2018 Unemployment_rate_2018 out_movement HospCt SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool 2wk Prior Mobility
# score: 0.006519508406746865
# Unnamed: 0                                                                                           0.0000
# 2wk Post Mobility                                                                                    0.0006
# inter_movement                                                                                       0.0022
# baseline m50 mobility                                                                                -0.0016
# Rural-urban_Continuum Code_2013                                                                      0.0102
# Percent of adults with less than a high school diploma 2014-18                                       0.0062
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0061
# Total households!!Average household size                                                             -0.0071
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0035
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0252
# *** SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         0.0259
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        0.0037
# Longterm Beds                                                                                        -0.0139
# Hispanic Population                                                                                  0.0017
# Black Population                                                                                     0.0108
# Time from outbreak to intervention                                                                   0.0045
#
#
# max var:  SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)
#
#
#
#
# Iteration 11
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility Med_HH_Income_Percent_of_State_Total_2018 Unemployment_rate_2018 out_movement HospCt SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool 2wk Prior Mobility SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)
# score: 0.006442402130350078
# Unnamed: 0                                                                                           0.0000
# 2wk Post Mobility                                                                                    0.0017
# inter_movement                                                                                       -0.0038
# baseline m50 mobility                                                                                -0.0004
# Rural-urban_Continuum Code_2013                                                                      0.0068
# Percent of adults with less than a high school diploma 2014-18                                       0.0057
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0078
# Total households!!Average household size                                                             -0.0073
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      -0.0033
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0010
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0110
# Longterm Beds                                                                                        -0.0073
# Hispanic Population                                                                                  0.0118
# Black Population                                                                                     0.0046
# *** Time from outbreak to intervention                                                                   -0.0179
#
#
# max var:  Time from outbreak to intervention
#
#
#
#
# Iteration 12
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility Med_HH_Income_Percent_of_State_Total_2018 Unemployment_rate_2018 out_movement HospCt SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool 2wk Prior Mobility SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12) Time from outbreak to intervention
# score: 0.0030178112232215337
# Unnamed: 0                                                                                           0.0000
# 2wk Post Mobility                                                                                    -0.0012
# inter_movement                                                                                       -0.0003
# baseline m50 mobility                                                                                -0.0020
# *** Rural-urban_Continuum Code_2013                                                                      0.0084
# Percent of adults with less than a high school diploma 2014-18                                       -0.0031
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0032
# Total households!!Average household size                                                             0.0005
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      0.0049
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0035
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0082
# Longterm Beds                                                                                        -0.0081
# Hispanic Population                                                                                  0.0052
# Black Population                                                                                     0.0066
#
#
# max var:  Rural-urban_Continuum Code_2013
#
#
#
#
# Iteration 13
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility Med_HH_Income_Percent_of_State_Total_2018 Unemployment_rate_2018 out_movement HospCt SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool 2wk Prior Mobility SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12) Time from outbreak to intervention Rural-urban_Continuum Code_2013
# score: 0.000410173918129364
# Unnamed: 0                                                                                           0.0000
# 2wk Post Mobility                                                                                    -0.0015
# inter_movement                                                                                       0.0003
# baseline m50 mobility                                                                                -0.0006
# Percent of adults with less than a high school diploma 2014-18                                       0.0004
# Percent of adults with a bachelor's degree or higher 2014-18                                         0.0002
# Total households!!Average household size                                                             0.0023
# *** SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      0.0095
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Elementary school (grades 1-8)    -0.0068
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!College or graduate school        -0.0023
# Longterm Beds                                                                                        -0.0006
# Hispanic Population                                                                                  0.0007
# Black Population                                                                                     0.0003
#
#
# max var:  SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten
#
#
#
#
# Iteration 14
# confounders: Density per square mile of land area - Population Total_age65plus Outbreak Month Temp AVG / F 2wk Onset Mobility Med_HH_Income_Percent_of_State_Total_2018 Unemployment_rate_2018 out_movement HospCt SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool 2wk Prior Mobility SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12) Time from outbreak to intervention Rural-urban_Continuum Code_2013 SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten
#
#
#
#
# Density per square mile of land area - Population                                                    & 0.9555 \\hline
# Total_age65plus                                                                                      & 0.1959 \\hline
# Outbreak Month Temp AVG / F                                                                          & -0.0657 \\hline
# 2wk Onset Mobility                                                                                   & -0.0979 \\hline
# Med_HH_Income_Percent_of_State_Total_2018                                                            & -0.0781 \\hline
# Unemployment_rate_2018                                                                               & 0.0741 \\hline
# out_movement                                                                                         & 0.0518 \\hline
# HospCt                                                                                               & 0.0385 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Nursery school preschool          & 0.0370 \\hline
# 2wk Prior Mobility                                                                                   & 0.0398 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!High school (grades 9-12)         & 0.0259 \\hline
# Time from outbreak to intervention                                                                   & -0.0179 \\hline
# Rural-urban_Continuum Code_2013                                                                      & 0.0084 \\hline
# SCHOOL ENROLLMENT!!Population 3 years and over enrolled in school!!Kindergarten                      & 0.0095 \\hline

# %% [raw]
# problems: 2wk mobility averages and time from outbreak to intervention should all be positive

# %% [raw]
# interventon date - outbreak
# neg if intervention happens before outbreak (neg in most cases)
# pos if outbreak before intervention
# 0 if same day
